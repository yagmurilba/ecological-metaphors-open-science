# %% [markdown]
# # Knowledge Graph - Relations Extraction

# %%
import openai
import json
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import os
import re
import tiktoken

# === Global accumulator ===
all_articles_data = []

# === 0. Text Extraction from Different Formats ===
def extract_text_from_file(file_path):
    ext = os.path.splitext(file_path)[1].lower()

    if ext == ".txt":
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()

    elif ext == ".pdf":
        try:
            from PyPDF2 import PdfReader
        except ImportError:
            raise ImportError("You need to install PyPDF2! Run: pip install PyPDF2")

        reader = PdfReader(file_path)
        text = ""
        for page in reader.pages:
            text += page.extract_text()
        return text

    else:
        raise ValueError(f"Unsupported file extension: {ext}")

# === 1. Helper: Token Counter and Splitter ===
def num_tokens_from_text(text, model="gpt-3.5-turbo"):
    encoding = tiktoken.encoding_for_model(model)
    return len(encoding.encode(text))

def split_text(text, max_tokens=3000, model="gpt-3.5-turbo"):
    encoding = tiktoken.encoding_for_model(model)
    tokens = encoding.encode(text)

    chunks = []
    for i in range(0, len(tokens), max_tokens):
        chunk_tokens = tokens[i:i + max_tokens]
        chunk_text = encoding.decode(chunk_tokens)
        chunks.append(chunk_text)

    return chunks

# === 2. Build Prompt for GPT ===
def build_prompt(text):
    return f"""
You are an expert in knowledge extraction.

Your task:
- Focus ONLY on text where the word "ecosystem" appears.
- From those parts, extract meaningful, well-formed entities (as nodes) and their relationships (as triples).

Guidelines:
- Include any terms that directly contain the word "ecosystem" (e.g., "Open Science Ecosystem", "Blockchain Ecosystem") as part of the **concept list**. 
- Only include entities that are concrete or conceptual — no vague or generic entries.
- Limit to a **maximum of 20 concepts** and **maximum of 20 relations**.
- It is perfectly fine if there are fewer than 20 concepts or relations, depending on the richness of the information.
- Do NOT invent or hallucinate content that is not explicitly or implicitly supported by the text.
- Prioritize clarity, importance, and relevance.
- Avoid very long phrases (keep concept labels under 6-7 words).
- For relations, avoid generic verbs like "is", "are", or conjugated forms like "includes". Use meaningful, specific verbs (e.g., "participate in", "enable", "comprise").

Output Format (strictly):
Return a valid JSON object with exactly these two keys:
- "concepts": a list of important concept strings
- "relations": a list of [subject, relation, object] triples

Example:
{{
  "concepts": ["Open Science Ecosystem", "Repositories", "Researchers", "Knowledge Sharing"],
  "relations": [
    ["Researchers", "participate in", "Open Science Ecosystem"],
    ["Repositories", "enable", "Knowledge Sharing"]
  ]
}}

Strict instructions:
- Only return the JSON object — no explanations, commentary, or extra text.
- Do not repeat terms unnecessarily.
- Ensure that the JSON is valid (no missing commas, brackets, or quotation marks).

TEXT:
---
{text}
---
"""

# === 3. Extract Knowledge Using GPT ===
def extract_knowledge(text, model="gpt-3.5-turbo"):
    prompt = build_prompt(text)
    response = openai.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=0.0
    )
    content = response.choices[0].message.content.strip()

    try:
        data = json.loads(content)
        if "concepts" not in data or "relations" not in data:
            raise ValueError("Missing 'concepts' or 'relations' keys.")
        return data
    except Exception as e:
        print("❌ Error parsing GPT output:", e)
        print("Content was:\n", content)
        raise

# === 4. Save Outputs to JSON, Excel, and PNG ===
def save_outputs(data, base_path, article_no=None, chunk_idx=None):
    chunk_suffix = f"_chunk{chunk_idx}" if chunk_idx is not None else ""
    suffix = f"_article{article_no}{chunk_suffix}" if article_no is not None else chunk_suffix

    json_path = f"{base_path}{suffix}_graph.json"
    excel_path = f"{base_path}{suffix}_graph.xlsx"

    with open(json_path, "w", encoding="utf-8") as f:
        json.dump(data, f, indent=2, ensure_ascii=False)

    df = pd.DataFrame(data["relations"], columns=["Subject", "Relation", "Object"])
    df["Article No"] = article_no
    df.to_excel(excel_path, index=False)

    print(f"✅ Saved JSON to {json_path}")
    print(f"✅ Saved Excel to {excel_path}")
    print(f"📌 Concepts: {len(data['concepts'])} | Relations: {len(data['relations'])}")

def save_graph_image(data, path, title="Knowledge Graph", seed=42):
    G = nx.DiGraph()
    skipped = 0

    for relation in data.get("relations", []):
        if isinstance(relation, list) and len(relation) == 3:
            s, r, o = relation
            G.add_edge(s, o, relation=r)
        else:
            skipped += 1
            print(f"⚠️ Skipping malformed relation (not a triple): {relation}")

    try:
        pos = nx.spring_layout(G, seed=seed, k=0.6)
        plt.figure(figsize=(18, 14))
        nx.draw_networkx_nodes(G, pos, node_color="lightblue", node_size=700, edgecolors='black')
        nx.draw_networkx_edges(G, pos, arrows=True, arrowstyle='-|>', width=2, arrowsize=20)
        nx.draw_networkx_labels(G, pos, font_size=10, font_weight="bold")

        edge_labels = {(u, v): d.get("relation", "") for u, v, d in G.edges(data=True)}
        nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=8, font_color="darkred")

        plt.title(title)
        plt.axis("off")
        plt.tight_layout()
        plt.savefig(path)
        plt.close()
        print(f"🖼️ Saved graph visualization: {path}")
        if skipped > 0:
            print(f"⚠️ {skipped} malformed relations were skipped in graph rendering.")
    except Exception as e:
        print(f"❌ Error during graph rendering: {e}")

# === 5. Full Processing Pipeline for One Article ===
def process_article_from_file(file_path, save_base="output/article_knowledge"):
    match = re.search(r"(\d+)", os.path.splitext(os.path.basename(file_path))[0])
    article_no = match.group(1) if match else "unknown"

    output_dir = os.path.dirname(save_base)
    if output_dir and not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"📁 Created directory: {output_dir}")

    print(f"📄 Loading and processing file: {file_path}")
    text = extract_text_from_file(file_path)

    total_tokens = num_tokens_from_text(text)
    print(f"🧮 Text token count: {total_tokens}")

    if total_tokens > 14000:
        print("⚡ Text too large: Splitting into chunks...")
        chunks = split_text(text, max_tokens=12000)
    else:
        chunks = [text]

    for idx, chunk in enumerate(chunks):
        print(f"🔎 Processing chunk {idx+1}/{len(chunks)}...")
        try:
            data = extract_knowledge(chunk)
            data["article_no"] = article_no
            data["chunk_idx"] = idx if len(chunks) > 1 else 0

            save_outputs(data, save_base, article_no=article_no, chunk_idx=idx if len(chunks) > 1 else None)

            img_path = f"{save_base}_article{article_no}_chunk{idx}_graph.png"
            save_graph_image(data, img_path, title=f"Knowledge Graph: Article {article_no} Chunk {idx}")

            all_articles_data.append({
                "article_no": article_no,
                "chunk_idx": idx if len(chunks) > 1 else 0,
                "concepts": data["concepts"],
                "relations": data["relations"],
                "num_concepts": len(data["concepts"]),
                "num_relations": len(data["relations"])
            })
        except Exception as e:
            print(f"❌ Error processing chunk {idx} of article {article_no}: {e}")

# === 6. Batch Processing ===
def process_multiple_articles(folder_path, max_files=10, save_base="output/article_knowledge", final_master_path="output/master_knowledge.json"):
    files = sorted([
        f for f in os.listdir(folder_path)
        if f.lower().endswith((".pdf", ".txt"))
    ])[:max_files]

    print(f"🔁 Found {len(files)} files. Processing first {max_files}...\n")

    for file in files:
        file_path = os.path.join(folder_path, file)
        process_article_from_file(file_path, save_base=save_base)

    print(f"\n📦 Saving master file with {len(all_articles_data)} entries to {final_master_path}...")
    with open(final_master_path, "w", encoding="utf-8") as f:
        json.dump(all_articles_data, f, indent=2, ensure_ascii=False)
    print(f"✅ Master JSON saved!")

# %%
process_multiple_articles(
    folder_path="/Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try", 
    max_files=211, 
    save_base="output5/04.29_KG_",
    final_master_path="output5/04.29_master_knowledge.json"
)
# Out:
# 🔁 Found 204 files. Processing first 211...
#
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/111.txt
# 🧮 Text token count: 28877
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/3...
# ✅ Saved JSON to output5/04.29_KG__article111_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article111_chunk0_graph.xlsx
# 📌 Concepts: 11 | Relations: 29
# 🖼️ Saved graph visualization: output5/04.29_KG__article111_chunk0_graph.png
# 🔎 Processing chunk 2/3...
# ✅ Saved JSON to output5/04.29_KG__article111_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article111_chunk1_graph.xlsx
# 📌 Concepts: 18 | Relations: 19
# 🖼️ Saved graph visualization: output5/04.29_KG__article111_chunk1_graph.png
# 🔎 Processing chunk 3/3...
# ✅ Saved JSON to output5/04.29_KG__article111_chunk2_graph.json
# ✅ Saved Excel to output5/04.29_KG__article111_chunk2_graph.xlsx
# 📌 Concepts: 20 | Relations: 13
# 🖼️ Saved graph visualization: output5/04.29_KG__article111_chunk2_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/114.txt
# 🧮 Text token count: 17082
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article114_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article114_chunk0_graph.xlsx
# 📌 Concepts: 10 | Relations: 10
# 🖼️ Saved graph visualization: output5/04.29_KG__article114_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article114_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article114_chunk1_graph.xlsx
# 📌 Concepts: 20 | Relations: 18
# 🖼️ Saved graph visualization: output5/04.29_KG__article114_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/116.txt
# 🧮 Text token count: 17624
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article116_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article116_chunk0_graph.xlsx
# 📌 Concepts: 20 | Relations: 18
# 🖼️ Saved graph visualization: output5/04.29_KG__article116_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article116_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article116_chunk1_graph.xlsx
# 📌 Concepts: 20 | Relations: 12
# 🖼️ Saved graph visualization: output5/04.29_KG__article116_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/117.txt
# 🧮 Text token count: 11495
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article117_graph.json
# ✅ Saved Excel to output5/04.29_KG__article117_graph.xlsx
# 📌 Concepts: 20 | Relations: 18
# 🖼️ Saved graph visualization: output5/04.29_KG__article117_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/12.txt
# 🧮 Text token count: 2200
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article12_graph.json
# ✅ Saved Excel to output5/04.29_KG__article12_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article12_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/120.txt
# 🧮 Text token count: 4497
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article120_graph.json
# ✅ Saved Excel to output5/04.29_KG__article120_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article120_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/122.txt
# 🧮 Text token count: 7970
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article122_graph.json
# ✅ Saved Excel to output5/04.29_KG__article122_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article122_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/123.txt
# 🧮 Text token count: 12277
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article123_graph.json
# ✅ Saved Excel to output5/04.29_KG__article123_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article123_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/125.txt
# 🧮 Text token count: 21172
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article125_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article125_chunk0_graph.xlsx
# 📌 Concepts: 18 | Relations: 18
# 🖼️ Saved graph visualization: output5/04.29_KG__article125_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article125_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article125_chunk1_graph.xlsx
# 📌 Concepts: 10 | Relations: 10
# 🖼️ Saved graph visualization: output5/04.29_KG__article125_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/127.txt
# 🧮 Text token count: 3840
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article127_graph.json
# ✅ Saved Excel to output5/04.29_KG__article127_graph.xlsx
# 📌 Concepts: 10 | Relations: 11
# 🖼️ Saved graph visualization: output5/04.29_KG__article127_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/129.txt
# 🧮 Text token count: 5779
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article129_graph.json
# ✅ Saved Excel to output5/04.29_KG__article129_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article129_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/13.txt
# 🧮 Text token count: 20331
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article13_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article13_chunk0_graph.xlsx
# 📌 Concepts: 20 | Relations: 19
# 🖼️ Saved graph visualization: output5/04.29_KG__article13_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article13_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article13_chunk1_graph.xlsx
# 📌 Concepts: 20 | Relations: 18
# 🖼️ Saved graph visualization: output5/04.29_KG__article13_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/130.txt
# 🧮 Text token count: 22437
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article130_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article130_chunk0_graph.xlsx
# 📌 Concepts: 10 | Relations: 9
# 🖼️ Saved graph visualization: output5/04.29_KG__article130_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article130_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article130_chunk1_graph.xlsx
# 📌 Concepts: 20 | Relations: 15
# 🖼️ Saved graph visualization: output5/04.29_KG__article130_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/131.txt
# 🧮 Text token count: 8656
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article131_graph.json
# ✅ Saved Excel to output5/04.29_KG__article131_graph.xlsx
# 📌 Concepts: 20 | Relations: 13
# 🖼️ Saved graph visualization: output5/04.29_KG__article131_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/134.txt
# 🧮 Text token count: 706
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article134_graph.json
# ✅ Saved Excel to output5/04.29_KG__article134_graph.xlsx
# 📌 Concepts: 19 | Relations: 16
# 🖼️ Saved graph visualization: output5/04.29_KG__article134_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/137.txt
# 🧮 Text token count: 6306
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article137_graph.json
# ✅ Saved Excel to output5/04.29_KG__article137_graph.xlsx
# 📌 Concepts: 20 | Relations: 15
# 🖼️ Saved graph visualization: output5/04.29_KG__article137_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/138.txt
# 🧮 Text token count: 2770
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article138_graph.json
# ✅ Saved Excel to output5/04.29_KG__article138_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# ⚠️ Skipping malformed relation (not a triple): ['Open Source Hardware', 'is shared in ways to give everyone the freedom to learn and understand']
# ⚠️ Skipping malformed relation (not a triple): ['Open Source Hardware', 'is more affordable, adaptable, and sustainable than proprietary products']
# 🖼️ Saved graph visualization: output5/04.29_KG__article138_chunk0_graph.png
# ⚠️ 2 malformed relations were skipped in graph rendering.
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/139.txt
# 🧮 Text token count: 21498
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article139_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article139_chunk0_graph.xlsx
# 📌 Concepts: 10 | Relations: 8
# 🖼️ Saved graph visualization: output5/04.29_KG__article139_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article139_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article139_chunk1_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article139_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/14.txt
# 🧮 Text token count: 3233
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article14_graph.json
# ✅ Saved Excel to output5/04.29_KG__article14_graph.xlsx
# 📌 Concepts: 19 | Relations: 14
# 🖼️ Saved graph visualization: output5/04.29_KG__article14_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/142.txt
# 🧮 Text token count: 31758
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/3...
# ✅ Saved JSON to output5/04.29_KG__article142_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article142_chunk0_graph.xlsx
# 📌 Concepts: 20 | Relations: 21
# 🖼️ Saved graph visualization: output5/04.29_KG__article142_chunk0_graph.png
# 🔎 Processing chunk 2/3...
# ✅ Saved JSON to output5/04.29_KG__article142_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article142_chunk1_graph.xlsx
# 📌 Concepts: 10 | Relations: 8
# 🖼️ Saved graph visualization: output5/04.29_KG__article142_chunk1_graph.png
# 🔎 Processing chunk 3/3...
# ✅ Saved JSON to output5/04.29_KG__article142_chunk2_graph.json
# ✅ Saved Excel to output5/04.29_KG__article142_chunk2_graph.xlsx
# 📌 Concepts: 10 | Relations: 9
# 🖼️ Saved graph visualization: output5/04.29_KG__article142_chunk2_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/145.txt
# 🧮 Text token count: 17470
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article145_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article145_chunk0_graph.xlsx
# 📌 Concepts: 10 | Relations: 9
# 🖼️ Saved graph visualization: output5/04.29_KG__article145_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article145_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article145_chunk1_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article145_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/147.txt
# 🧮 Text token count: 18889
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article147_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article147_chunk0_graph.xlsx
# 📌 Concepts: 10 | Relations: 9
# 🖼️ Saved graph visualization: output5/04.29_KG__article147_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article147_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article147_chunk1_graph.xlsx
# 📌 Concepts: 20 | Relations: 19
# 🖼️ Saved graph visualization: output5/04.29_KG__article147_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/149.txt
# 🧮 Text token count: 16031
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article149_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article149_chunk0_graph.xlsx
# 📌 Concepts: 19 | Relations: 27
# 🖼️ Saved graph visualization: output5/04.29_KG__article149_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article149_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article149_chunk1_graph.xlsx
# 📌 Concepts: 20 | Relations: 16
# 🖼️ Saved graph visualization: output5/04.29_KG__article149_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/152.txt
# 🧮 Text token count: 3244
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article152_graph.json
# ✅ Saved Excel to output5/04.29_KG__article152_graph.xlsx
# 📌 Concepts: 19 | Relations: 15
# 🖼️ Saved graph visualization: output5/04.29_KG__article152_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/158.txt
# 🧮 Text token count: 2307
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article158_graph.json
# ✅ Saved Excel to output5/04.29_KG__article158_graph.xlsx
# 📌 Concepts: 20 | Relations: 18
# 🖼️ Saved graph visualization: output5/04.29_KG__article158_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/160.txt
# 🧮 Text token count: 16460
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article160_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article160_chunk0_graph.xlsx
# 📌 Concepts: 10 | Relations: 8
# 🖼️ Saved graph visualization: output5/04.29_KG__article160_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article160_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article160_chunk1_graph.xlsx
# 📌 Concepts: 10 | Relations: 10
# 🖼️ Saved graph visualization: output5/04.29_KG__article160_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/162.txt
# 🧮 Text token count: 14934
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article162_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article162_chunk0_graph.xlsx
# 📌 Concepts: 12 | Relations: 12
# 🖼️ Saved graph visualization: output5/04.29_KG__article162_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article162_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article162_chunk1_graph.xlsx
# 📌 Concepts: 10 | Relations: 7
# 🖼️ Saved graph visualization: output5/04.29_KG__article162_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/163.txt
# 🧮 Text token count: 13149
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article163_graph.json
# ✅ Saved Excel to output5/04.29_KG__article163_graph.xlsx
# 📌 Concepts: 20 | Relations: 17
# 🖼️ Saved graph visualization: output5/04.29_KG__article163_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/166.txt
# 🧮 Text token count: 4650
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article166_graph.json
# ✅ Saved Excel to output5/04.29_KG__article166_graph.xlsx
# 📌 Concepts: 20 | Relations: 18
# 🖼️ Saved graph visualization: output5/04.29_KG__article166_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/17.txt
# 🧮 Text token count: 16371
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article17_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article17_chunk0_graph.xlsx
# 📌 Concepts: 10 | Relations: 11
# 🖼️ Saved graph visualization: output5/04.29_KG__article17_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article17_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article17_chunk1_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article17_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/170.txt
# 🧮 Text token count: 5070
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article170_graph.json
# ✅ Saved Excel to output5/04.29_KG__article170_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article170_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/174.txt
# 🧮 Text token count: 11615
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article174_graph.json
# ✅ Saved Excel to output5/04.29_KG__article174_graph.xlsx
# 📌 Concepts: 18 | Relations: 17
# 🖼️ Saved graph visualization: output5/04.29_KG__article174_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/176.txt
# 🧮 Text token count: 25107
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/3...
# ✅ Saved JSON to output5/04.29_KG__article176_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article176_chunk0_graph.xlsx
# 📌 Concepts: 20 | Relations: 10
# 🖼️ Saved graph visualization: output5/04.29_KG__article176_chunk0_graph.png
# 🔎 Processing chunk 2/3...
# ✅ Saved JSON to output5/04.29_KG__article176_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article176_chunk1_graph.xlsx
# 📌 Concepts: 20 | Relations: 16
# 🖼️ Saved graph visualization: output5/04.29_KG__article176_chunk1_graph.png
# 🔎 Processing chunk 3/3...
# ✅ Saved JSON to output5/04.29_KG__article176_chunk2_graph.json
# ✅ Saved Excel to output5/04.29_KG__article176_chunk2_graph.xlsx
# 📌 Concepts: 8 | Relations: 8
# 🖼️ Saved graph visualization: output5/04.29_KG__article176_chunk2_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/178.txt
# 🧮 Text token count: 31025
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/3...
# ✅ Saved JSON to output5/04.29_KG__article178_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article178_chunk0_graph.xlsx
# 📌 Concepts: 20 | Relations: 14
# ⚠️ Skipping malformed relation (not a triple): ['Open Access', 'enables content to be free to read and reuse']
# ⚠️ Skipping malformed relation (not a triple): ['E-science', 'uses digital tools for distributed and collaborative production of knowledge']
# ⚠️ Skipping malformed relation (not a triple): ['Digital Repositories', 'store research for open access']
# ⚠️ Skipping malformed relation (not a triple): ['Scientific Research', 'embraces opportunities offered by networked computing']
# ⚠️ Skipping malformed relation (not a triple): ['Knowledge Production Regimes', 'evolving in the age of openness']
# ⚠️ Skipping malformed relation (not a triple): ['Scientific Norms', 'include communism, universalism, disinterestedness, and organized skepticism']
# ⚠️ Skipping malformed relation (not a triple): ['Collaborative Knowledge Production', 'involves private and collective aspects of innovation and knowledge']
# ⚠️ Skipping malformed relation (not a triple): ['Public Good', 'created through collaborative efforts in Open Source Software development']
# ⚠️ Skipping malformed relation (not a triple): ['Knowledge Sharing', 'facilitated by technology for crowdsourced approaches to data collection']
# ⚠️ Skipping malformed relation (not a triple): ['Societal Impact', 'addressed through open knowledge production for societal improvement']
# 🖼️ Saved graph visualization: output5/04.29_KG__article178_chunk0_graph.png
# ⚠️ 10 malformed relations were skipped in graph rendering.
# 🔎 Processing chunk 2/3...
# ✅ Saved JSON to output5/04.29_KG__article178_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article178_chunk1_graph.xlsx
# 📌 Concepts: 19 | Relations: 14
# 🖼️ Saved graph visualization: output5/04.29_KG__article178_chunk1_graph.png
# 🔎 Processing chunk 3/3...
# ✅ Saved JSON to output5/04.29_KG__article178_chunk2_graph.json
# ✅ Saved Excel to output5/04.29_KG__article178_chunk2_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article178_chunk2_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/179.txt
# 🧮 Text token count: 6441
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article179_graph.json
# ✅ Saved Excel to output5/04.29_KG__article179_graph.xlsx
# 📌 Concepts: 20 | Relations: 16
# 🖼️ Saved graph visualization: output5/04.29_KG__article179_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/18.txt
# 🧮 Text token count: 15271
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article18_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article18_chunk0_graph.xlsx
# 📌 Concepts: 20 | Relations: 14
# 🖼️ Saved graph visualization: output5/04.29_KG__article18_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article18_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article18_chunk1_graph.xlsx
# 📌 Concepts: 10 | Relations: 10
# 🖼️ Saved graph visualization: output5/04.29_KG__article18_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/180.txt
# 🧮 Text token count: 18567
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article180_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article180_chunk0_graph.xlsx
# 📌 Concepts: 14 | Relations: 10
# 🖼️ Saved graph visualization: output5/04.29_KG__article180_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article180_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article180_chunk1_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article180_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/183.txt
# 🧮 Text token count: 7949
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article183_graph.json
# ✅ Saved Excel to output5/04.29_KG__article183_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article183_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/184.txt
# 🧮 Text token count: 17259
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article184_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article184_chunk0_graph.xlsx
# 📌 Concepts: 20 | Relations: 17
# 🖼️ Saved graph visualization: output5/04.29_KG__article184_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article184_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article184_chunk1_graph.xlsx
# 📌 Concepts: 10 | Relations: 10
# 🖼️ Saved graph visualization: output5/04.29_KG__article184_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/185.txt
# 🧮 Text token count: 12022
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article185_graph.json
# ✅ Saved Excel to output5/04.29_KG__article185_graph.xlsx
# 📌 Concepts: 16 | Relations: 16
# 🖼️ Saved graph visualization: output5/04.29_KG__article185_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/187.txt
# 🧮 Text token count: 3405
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article187_graph.json
# ✅ Saved Excel to output5/04.29_KG__article187_graph.xlsx
# 📌 Concepts: 19 | Relations: 18
# 🖼️ Saved graph visualization: output5/04.29_KG__article187_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/19.txt
# 🧮 Text token count: 19964
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article19_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article19_chunk0_graph.xlsx
# 📌 Concepts: 20 | Relations: 19
# ⚠️ Skipping malformed relation (not a triple): ['GIS Database of Nairobi', "enhanced Google's Points of Interest data for Google map of Nairobi"]
# 🖼️ Saved graph visualization: output5/04.29_KG__article19_chunk0_graph.png
# ⚠️ 1 malformed relations were skipped in graph rendering.
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article19_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article19_chunk1_graph.xlsx
# 📌 Concepts: 20 | Relations: 19
# 🖼️ Saved graph visualization: output5/04.29_KG__article19_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/196.txt
# 🧮 Text token count: 30309
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/3...
# ✅ Saved JSON to output5/04.29_KG__article196_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article196_chunk0_graph.xlsx
# 📌 Concepts: 20 | Relations: 17
# 🖼️ Saved graph visualization: output5/04.29_KG__article196_chunk0_graph.png
# 🔎 Processing chunk 2/3...
# ✅ Saved JSON to output5/04.29_KG__article196_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article196_chunk1_graph.xlsx
# 📌 Concepts: 20 | Relations: 16
# 🖼️ Saved graph visualization: output5/04.29_KG__article196_chunk1_graph.png
# 🔎 Processing chunk 3/3...
# ✅ Saved JSON to output5/04.29_KG__article196_chunk2_graph.json
# ✅ Saved Excel to output5/04.29_KG__article196_chunk2_graph.xlsx
# 📌 Concepts: 20 | Relations: 11
# 🖼️ Saved graph visualization: output5/04.29_KG__article196_chunk2_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/198.txt
# 🧮 Text token count: 13113
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article198_graph.json
# ✅ Saved Excel to output5/04.29_KG__article198_graph.xlsx
# 📌 Concepts: 20 | Relations: 16
# 🖼️ Saved graph visualization: output5/04.29_KG__article198_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/199.txt
# 🧮 Text token count: 9039
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article199_graph.json
# ✅ Saved Excel to output5/04.29_KG__article199_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article199_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/2.txt
# 🧮 Text token count: 19137
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article2_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article2_chunk0_graph.xlsx
# 📌 Concepts: 12 | Relations: 5
# 🖼️ Saved graph visualization: output5/04.29_KG__article2_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article2_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article2_chunk1_graph.xlsx
# 📌 Concepts: 20 | Relations: 16
# 🖼️ Saved graph visualization: output5/04.29_KG__article2_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/20.txt
# 🧮 Text token count: 79768
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/7...
# ✅ Saved JSON to output5/04.29_KG__article20_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article20_chunk0_graph.xlsx
# 📌 Concepts: 20 | Relations: 26
# 🖼️ Saved graph visualization: output5/04.29_KG__article20_chunk0_graph.png
# 🔎 Processing chunk 2/7...
# ✅ Saved JSON to output5/04.29_KG__article20_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article20_chunk1_graph.xlsx
# 📌 Concepts: 16 | Relations: 14
# 🖼️ Saved graph visualization: output5/04.29_KG__article20_chunk1_graph.png
# 🔎 Processing chunk 3/7...
# ✅ Saved JSON to output5/04.29_KG__article20_chunk2_graph.json
# ✅ Saved Excel to output5/04.29_KG__article20_chunk2_graph.xlsx
# 📌 Concepts: 10 | Relations: 10
# 🖼️ Saved graph visualization: output5/04.29_KG__article20_chunk2_graph.png
# 🔎 Processing chunk 4/7...
# ✅ Saved JSON to output5/04.29_KG__article20_chunk3_graph.json
# ✅ Saved Excel to output5/04.29_KG__article20_chunk3_graph.xlsx
# 📌 Concepts: 10 | Relations: 10
# 🖼️ Saved graph visualization: output5/04.29_KG__article20_chunk3_graph.png
# 🔎 Processing chunk 5/7...
# ✅ Saved JSON to output5/04.29_KG__article20_chunk4_graph.json
# ✅ Saved Excel to output5/04.29_KG__article20_chunk4_graph.xlsx
# 📌 Concepts: 10 | Relations: 14
# 🖼️ Saved graph visualization: output5/04.29_KG__article20_chunk4_graph.png
# 🔎 Processing chunk 6/7...
# ✅ Saved JSON to output5/04.29_KG__article20_chunk5_graph.json
# ✅ Saved Excel to output5/04.29_KG__article20_chunk5_graph.xlsx
# 📌 Concepts: 20 | Relations: 18
# 🖼️ Saved graph visualization: output5/04.29_KG__article20_chunk5_graph.png
# 🔎 Processing chunk 7/7...
# ✅ Saved JSON to output5/04.29_KG__article20_chunk6_graph.json
# ✅ Saved Excel to output5/04.29_KG__article20_chunk6_graph.xlsx
# 📌 Concepts: 10 | Relations: 7
# 🖼️ Saved graph visualization: output5/04.29_KG__article20_chunk6_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/201.txt
# 🧮 Text token count: 32824
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/3...
# ❌ Error parsing GPT output: Expecting value: line 1 column 1 (char 0)
# Content was:
#  Table 6 (continued)
#
# Condition
# characteristics
#
# Condition
#
# Adapted from Initial questions & scales
#
# Follow-up questions asked for
# each condition (based on response
# to initial question)
#
# Could you please tell me a bit
# more about why that is?
# Why didn’t you choose a
# lower/higher rating?
#
# Can you give me an example of
#
# this?
#
# I’d like to hear more about…
#
# To what extent do you believe that your organisation
#
# possesses the ability to absorb new knowledge, ranging
# from low capacity to high capacity?
#
# 1___2___3___4___5____6___7
# Low High
# ❌ Error processing chunk 0 of article 201: Expecting value: line 1 column 1 (char 0)
# 🔎 Processing chunk 2/3...
# ✅ Saved JSON to output5/04.29_KG__article201_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article201_chunk1_graph.xlsx
# 📌 Concepts: 10 | Relations: 9
# 🖼️ Saved graph visualization: output5/04.29_KG__article201_chunk1_graph.png
# 🔎 Processing chunk 3/3...
# ✅ Saved JSON to output5/04.29_KG__article201_chunk2_graph.json
# ✅ Saved Excel to output5/04.29_KG__article201_chunk2_graph.xlsx
# 📌 Concepts: 19 | Relations: 16
# 🖼️ Saved graph visualization: output5/04.29_KG__article201_chunk2_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/205.txt
# 🧮 Text token count: 5840
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article205_graph.json
# ✅ Saved Excel to output5/04.29_KG__article205_graph.xlsx
# 📌 Concepts: 11 | Relations: 11
# 🖼️ Saved graph visualization: output5/04.29_KG__article205_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/209.txt
# 🧮 Text token count: 4812
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article209_graph.json
# ✅ Saved Excel to output5/04.29_KG__article209_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article209_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/21.txt
# 🧮 Text token count: 290406
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk0_graph.xlsx
# 📌 Concepts: 20 | Relations: 18
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk0_graph.png
# 🔎 Processing chunk 2/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk1_graph.xlsx
# 📌 Concepts: 14 | Relations: 12
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk1_graph.png
# 🔎 Processing chunk 3/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk2_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk2_graph.xlsx
# 📌 Concepts: 10 | Relations: 8
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk2_graph.png
# 🔎 Processing chunk 4/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk3_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk3_graph.xlsx
# 📌 Concepts: 10 | Relations: 11
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk3_graph.png
# 🔎 Processing chunk 5/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk4_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk4_graph.xlsx
# 📌 Concepts: 10 | Relations: 8
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk4_graph.png
# 🔎 Processing chunk 6/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk5_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk5_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk5_graph.png
# 🔎 Processing chunk 7/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk6_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk6_graph.xlsx
# 📌 Concepts: 20 | Relations: 15
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk6_graph.png
# 🔎 Processing chunk 8/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk7_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk7_graph.xlsx
# 📌 Concepts: 20 | Relations: 21
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk7_graph.png
# 🔎 Processing chunk 9/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk8_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk8_graph.xlsx
# 📌 Concepts: 20 | Relations: 17
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk8_graph.png
# 🔎 Processing chunk 10/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk9_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk9_graph.xlsx
# 📌 Concepts: 12 | Relations: 13
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk9_graph.png
# 🔎 Processing chunk 11/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk10_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk10_graph.xlsx
# 📌 Concepts: 13 | Relations: 15
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk10_graph.png
# 🔎 Processing chunk 12/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk11_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk11_graph.xlsx
# 📌 Concepts: 20 | Relations: 14
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk11_graph.png
# 🔎 Processing chunk 13/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk12_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk12_graph.xlsx
# 📌 Concepts: 8 | Relations: 9
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk12_graph.png
# 🔎 Processing chunk 14/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk13_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk13_graph.xlsx
# 📌 Concepts: 7 | Relations: 5
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk13_graph.png
# 🔎 Processing chunk 15/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk14_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk14_graph.xlsx
# 📌 Concepts: 11 | Relations: 9
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk14_graph.png
# 🔎 Processing chunk 16/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk15_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk15_graph.xlsx
# 📌 Concepts: 20 | Relations: 13
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk15_graph.png
# 🔎 Processing chunk 17/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk16_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk16_graph.xlsx
# 📌 Concepts: 10 | Relations: 7
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk16_graph.png
# 🔎 Processing chunk 18/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk17_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk17_graph.xlsx
# 📌 Concepts: 10 | Relations: 11
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk17_graph.png
# 🔎 Processing chunk 19/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk18_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk18_graph.xlsx
# 📌 Concepts: 7 | Relations: 7
# ⚠️ Skipping malformed relation (not a triple): ['Webmention', 'mediates communication between data providers and aggregators']
# ⚠️ Skipping malformed relation (not a triple): ['Linked Data Notifications', 'allows data transmission in notifications']
# ⚠️ Skipping malformed relation (not a triple): ['Sitemaps', 'informs search engines about pages available for crawling']
# ⚠️ Skipping malformed relation (not a triple): ['ResourceSync', 'enables synchronization of digital objects between systems']
# ⚠️ Skipping malformed relation (not a triple): ['Open Publication Distribution System', 'enables aggregation, distribution, and discovery of digital content']
# ⚠️ Skipping malformed relation (not a triple): ['Linked Data Platform', 'specifies use of HTTP and RDF techniques for accessing and manipulating resources']
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk18_graph.png
# ⚠️ 6 malformed relations were skipped in graph rendering.
# 🔎 Processing chunk 20/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk19_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk19_graph.xlsx
# 📌 Concepts: 10 | Relations: 9
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk19_graph.png
# 🔎 Processing chunk 21/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk20_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk20_graph.xlsx
# 📌 Concepts: 20 | Relations: 10
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk20_graph.png
# 🔎 Processing chunk 22/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk21_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk21_graph.xlsx
# 📌 Concepts: 10 | Relations: 10
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk21_graph.png
# 🔎 Processing chunk 23/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk22_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk22_graph.xlsx
# 📌 Concepts: 8 | Relations: 7
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk22_graph.png
# 🔎 Processing chunk 24/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk23_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk23_graph.xlsx
# 📌 Concepts: 10 | Relations: 10
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk23_graph.png
# 🔎 Processing chunk 25/25...
# ✅ Saved JSON to output5/04.29_KG__article21_chunk24_graph.json
# ✅ Saved Excel to output5/04.29_KG__article21_chunk24_graph.xlsx
# 📌 Concepts: 20 | Relations: 19
# 🖼️ Saved graph visualization: output5/04.29_KG__article21_chunk24_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/216.txt
# 🧮 Text token count: 14684
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article216_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article216_chunk0_graph.xlsx
# 📌 Concepts: 17 | Relations: 17
# 🖼️ Saved graph visualization: output5/04.29_KG__article216_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article216_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article216_chunk1_graph.xlsx
# 📌 Concepts: 17 | Relations: 12
# 🖼️ Saved graph visualization: output5/04.29_KG__article216_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/217.txt
# 🧮 Text token count: 8995
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article217_graph.json
# ✅ Saved Excel to output5/04.29_KG__article217_graph.xlsx
# 📌 Concepts: 10 | Relations: 10
# 🖼️ Saved graph visualization: output5/04.29_KG__article217_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/220.txt
# 🧮 Text token count: 2428
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article220_graph.json
# ✅ Saved Excel to output5/04.29_KG__article220_graph.xlsx
# 📌 Concepts: 20 | Relations: 21
# 🖼️ Saved graph visualization: output5/04.29_KG__article220_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/222.txt
# 🧮 Text token count: 18332
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article222_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article222_chunk0_graph.xlsx
# 📌 Concepts: 10 | Relations: 10
# 🖼️ Saved graph visualization: output5/04.29_KG__article222_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article222_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article222_chunk1_graph.xlsx
# 📌 Concepts: 10 | Relations: 10
# 🖼️ Saved graph visualization: output5/04.29_KG__article222_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/223.txt
# 🧮 Text token count: 77186
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/7...
# ✅ Saved JSON to output5/04.29_KG__article223_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article223_chunk0_graph.xlsx
# 📌 Concepts: 29 | Relations: 29
# 🖼️ Saved graph visualization: output5/04.29_KG__article223_chunk0_graph.png
# 🔎 Processing chunk 2/7...
# ✅ Saved JSON to output5/04.29_KG__article223_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article223_chunk1_graph.xlsx
# 📌 Concepts: 21 | Relations: 18
# 🖼️ Saved graph visualization: output5/04.29_KG__article223_chunk1_graph.png
# 🔎 Processing chunk 3/7...
# ✅ Saved JSON to output5/04.29_KG__article223_chunk2_graph.json
# ✅ Saved Excel to output5/04.29_KG__article223_chunk2_graph.xlsx
# 📌 Concepts: 14 | Relations: 13
# 🖼️ Saved graph visualization: output5/04.29_KG__article223_chunk2_graph.png
# 🔎 Processing chunk 4/7...
# ✅ Saved JSON to output5/04.29_KG__article223_chunk3_graph.json
# ✅ Saved Excel to output5/04.29_KG__article223_chunk3_graph.xlsx
# 📌 Concepts: 18 | Relations: 17
# 🖼️ Saved graph visualization: output5/04.29_KG__article223_chunk3_graph.png
# 🔎 Processing chunk 5/7...
# ✅ Saved JSON to output5/04.29_KG__article223_chunk4_graph.json
# ✅ Saved Excel to output5/04.29_KG__article223_chunk4_graph.xlsx
# 📌 Concepts: 10 | Relations: 9
# 🖼️ Saved graph visualization: output5/04.29_KG__article223_chunk4_graph.png
# 🔎 Processing chunk 6/7...
# ✅ Saved JSON to output5/04.29_KG__article223_chunk5_graph.json
# ✅ Saved Excel to output5/04.29_KG__article223_chunk5_graph.xlsx
# 📌 Concepts: 5 | Relations: 5
# 🖼️ Saved graph visualization: output5/04.29_KG__article223_chunk5_graph.png
# 🔎 Processing chunk 7/7...
# ✅ Saved JSON to output5/04.29_KG__article223_chunk6_graph.json
# ✅ Saved Excel to output5/04.29_KG__article223_chunk6_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article223_chunk6_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/227.txt
# 🧮 Text token count: 14070
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article227_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article227_chunk0_graph.xlsx
# 📌 Concepts: 20 | Relations: 19
# 🖼️ Saved graph visualization: output5/04.29_KG__article227_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article227_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article227_chunk1_graph.xlsx
# 📌 Concepts: 11 | Relations: 8
# 🖼️ Saved graph visualization: output5/04.29_KG__article227_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/228.txt
# 🧮 Text token count: 12960
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article228_graph.json
# ✅ Saved Excel to output5/04.29_KG__article228_graph.xlsx
# 📌 Concepts: 20 | Relations: 23
# 🖼️ Saved graph visualization: output5/04.29_KG__article228_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/23.txt
# 🧮 Text token count: 5865
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article23_graph.json
# ✅ Saved Excel to output5/04.29_KG__article23_graph.xlsx
# 📌 Concepts: 20 | Relations: 17
# 🖼️ Saved graph visualization: output5/04.29_KG__article23_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/230.txt
# 🧮 Text token count: 32819
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/3...
# ✅ Saved JSON to output5/04.29_KG__article230_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article230_chunk0_graph.xlsx
# 📌 Concepts: 10 | Relations: 12
# 🖼️ Saved graph visualization: output5/04.29_KG__article230_chunk0_graph.png
# 🔎 Processing chunk 2/3...
# ✅ Saved JSON to output5/04.29_KG__article230_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article230_chunk1_graph.xlsx
# 📌 Concepts: 16 | Relations: 16
# 🖼️ Saved graph visualization: output5/04.29_KG__article230_chunk1_graph.png
# 🔎 Processing chunk 3/3...
# ✅ Saved JSON to output5/04.29_KG__article230_chunk2_graph.json
# ✅ Saved Excel to output5/04.29_KG__article230_chunk2_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article230_chunk2_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/233.txt
# 🧮 Text token count: 19332
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article233_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article233_chunk0_graph.xlsx
# 📌 Concepts: 12 | Relations: 10
# 🖼️ Saved graph visualization: output5/04.29_KG__article233_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article233_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article233_chunk1_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article233_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/236.txt
# 🧮 Text token count: 22425
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article236_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article236_chunk0_graph.xlsx
# 📌 Concepts: 19 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article236_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article236_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article236_chunk1_graph.xlsx
# 📌 Concepts: 20 | Relations: 14
# 🖼️ Saved graph visualization: output5/04.29_KG__article236_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/237.txt
# 🧮 Text token count: 1623
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article237_graph.json
# ✅ Saved Excel to output5/04.29_KG__article237_graph.xlsx
# 📌 Concepts: 22 | Relations: 20
# ...
# 🧮 Text token count: 1564
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article73_graph.json
# ✅ Saved Excel to output5/04.29_KG__article73_graph.xlsx
# 📌 Concepts: 20 | Relations: 19
# 🖼️ Saved graph visualization: output5/04.29_KG__article73_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/75.txt
# 🧮 Text token count: 3495
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article75_graph.json
# ✅ Saved Excel to output5/04.29_KG__article75_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article75_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/76.txt
# 🧮 Text token count: 28854
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/3...
# ✅ Saved JSON to output5/04.29_KG__article76_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article76_chunk0_graph.xlsx
# 📌 Concepts: 20 | Relations: 13
# 🖼️ Saved graph visualization: output5/04.29_KG__article76_chunk0_graph.png
# 🔎 Processing chunk 2/3...
# ✅ Saved JSON to output5/04.29_KG__article76_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article76_chunk1_graph.xlsx
# 📌 Concepts: 13 | Relations: 13
# 🖼️ Saved graph visualization: output5/04.29_KG__article76_chunk1_graph.png
# 🔎 Processing chunk 3/3...
# ✅ Saved JSON to output5/04.29_KG__article76_chunk2_graph.json
# ✅ Saved Excel to output5/04.29_KG__article76_chunk2_graph.xlsx
# 📌 Concepts: 20 | Relations: 19
# 🖼️ Saved graph visualization: output5/04.29_KG__article76_chunk2_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/78.txt
# 🧮 Text token count: 307247
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk0_graph.xlsx
# 📌 Concepts: 9 | Relations: 9
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk0_graph.png
# 🔎 Processing chunk 2/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk1_graph.xlsx
# 📌 Concepts: 12 | Relations: 21
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk1_graph.png
# 🔎 Processing chunk 3/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk2_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk2_graph.xlsx
# 📌 Concepts: 20 | Relations: 15
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk2_graph.png
# 🔎 Processing chunk 4/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk3_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk3_graph.xlsx
# 📌 Concepts: 9 | Relations: 9
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk3_graph.png
# 🔎 Processing chunk 5/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk4_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk4_graph.xlsx
# 📌 Concepts: 21 | Relations: 17
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk4_graph.png
# 🔎 Processing chunk 6/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk5_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk5_graph.xlsx
# 📌 Concepts: 23 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk5_graph.png
# 🔎 Processing chunk 7/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk6_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk6_graph.xlsx
# 📌 Concepts: 11 | Relations: 10
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk6_graph.png
# 🔎 Processing chunk 8/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk7_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk7_graph.xlsx
# 📌 Concepts: 10 | Relations: 8
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk7_graph.png
# 🔎 Processing chunk 9/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk8_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk8_graph.xlsx
# 📌 Concepts: 10 | Relations: 8
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk8_graph.png
# 🔎 Processing chunk 10/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk9_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk9_graph.xlsx
# 📌 Concepts: 11 | Relations: 11
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk9_graph.png
# 🔎 Processing chunk 11/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk10_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk10_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk10_graph.png
# 🔎 Processing chunk 12/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk11_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk11_graph.xlsx
# 📌 Concepts: 10 | Relations: 6
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk11_graph.png
# 🔎 Processing chunk 13/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk12_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk12_graph.xlsx
# 📌 Concepts: 10 | Relations: 9
# ⚠️ Skipping malformed relation (not a triple): ['Automated Program Repair', 'aims to convert a program that nearly satisfies a specification into one that fully satisfies it']
# ⚠️ Skipping malformed relation (not a triple): ['Software Transplantation', 'involves identifying code to transplant from a donor project to an implantation point in a host project']
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk12_graph.png
# ⚠️ 2 malformed relations were skipped in graph rendering.
# 🔎 Processing chunk 14/26...
# ❌ Error parsing GPT output: Expecting value: line 1 column 1 (char 0)
# Content was:
#  deprecated API. After that, variable normalization is applied to replace
# temporary variables in the update example with the resolved values. Finally,
# AndroEvolve creates the update script based on the resolved values and the
# variable normalization results.
#
# • Update-script application takes as input the update mapping, the after-update
# example, and the update script generated in the previous step. AndroEvolve
# applies the update script to the target code to update the deprecated API usages
# to the updated API usages.
#
# 7.3.3.2 Evaluation Results
#
# AndroEvolve is evaluated on the same dataset used in the CocciEvolve evaluation.
# The results show that AndroEvolve outperforms CocciEvolve in terms of the success
# rate of updating deprecated API usages. AndroEvolve achieves a success rate of
# 100% for all the investigated APIs, while CocciEvolve only achieves a success rate
# of 80%. The improved performance of AndroEvolve is attributed to the incorporation
# of data-ﬂow analysis and variable denormalization techniques, which enable the tool
# to resolve the values of out-of-method variables and handle temporary variables
# more effectively.
#
# 7.3.4 Related Work
#
# In the context of Android app development, there are several related works that
# focus on supporting collateral evolution. For example, AUSearch [3] is a tool that
# automatically identiﬁes API usages in Android apps by leveraging static analysis
# techniques. AppEvolve [12] is a tool that automatically updates deprecated API
# usages in Android apps using example-based program transformation. These tools
# provide valuable support for developers in maintaining their Android apps up to
# date with the latest API changes.
#
# 7.4 Supporting Collateral Evolution in Machine Learning
#
# In the context of machine learning (ML) software ecosystems, there is a need to
# support collateral evolution due to the rapid advancements and changes in ML
# libraries and frameworks. This section presents an approach to support collateral
# evolution in ML software ecosystems by leveraging type inference techniques to
# automatically update deprecated API usages in ML libraries.
#
# 7.4.1 Semantic Program Repair Using a Reference Implementation
#
# Mechtaev et al. proposed an approach [17] for automatically repairing semantic
# errors in ML software using a reference implementation. The approach leverages
# ❌ Error processing chunk 13 of article 78: Expecting value: line 1 column 1 (char 0)
# 🔎 Processing chunk 15/26...
# ❌ Error parsing GPT output: Expecting value: line 1 column 1 (char 0)
# Content was:
#  ,  on  the  other  hand,  extends  CI  by  automating  the  deployment  of  code  changes  to  production  environments  after  successful  testing  and  integration.  CD  aims  to  ensure  that  code  changes  are  always  in  a  deployable  state  and  can  be  released  to  users  at  any  time.
#
# CI/CD  practices  are  typically  supported  by  a  wide  range  of  tools  and  services  that  automate  the  building,  testing,  and  deployment  of  software  projects.  These  tools  include  Jenkins,  Travis  CI,  CircleCI,  GitLab  CI/CD,  and  GitHub  Actions.  They  help  to  increase  the  productivity  and  quality  of  software  projects  by  automating  repetitive  tasks,  reducing  human  error,  and  providing  fast  feedback  on  code  changes.
#
# 8.1.4  Development  Bots  and  GitHub  Actions
#
# Development  bots  and  GitHub  Actions  are  two  types  of  automation  solutions  that  have  emerged  as  highly  interconnected  ecosystems  to  support  CI/CD  practices  and  other  development-related  tasks  in  GitHub.
#
# Development  bots  are  software  programs  that  automate  various  tasks  in  the  software  development  process,  such  as  code  review,  issue  triaging,  and  deployment.  They  can  interact  with  developers  through  comments,  pull  requests,  and  other  communication  channels  to  provide  feedback  and  assistance.  Development  bots  can  be  integrated  with  external  CI/CD  tools  to  automate  the  testing  and  deployment  of  code  changes.
#
# GitHub  Actions,  on  the  other  hand,  is  a  native  CI/CD  tool  provided  by  GitHub  that  allows  developers  to  automate  their  development  workﬂows  directly  within  their  GitHub  repositories.  GitHub  Actions  uses  YAML  conﬁguration  ﬁles  to  deﬁne  the  steps  of  a  workﬂow,  such  as  building,  testing,  and  deploying  code.  It  provides  a  wide  range  of  pre-built  actions  and  integrations  with  external  services  to  automate  various  development  tasks.
#
# Together,  development  bots  and  GitHub  Actions  form  an  interconnected  ecosystem  that  supports  the  automation  of  software  development  tasks  in  GitHub.  They  help  to  streamline  the  development  process,  improve  code  quality,  and  increase  the  productivity  of  development  teams.
#
# In  the  following  sections,  we  will  explore  the  ecosystems  of  development  bots  and  GitHub  Actions  in  more  detail,  discussing  their  features,  use  cases,  challenges,  and  future  perspectives.
# ❌ Error processing chunk 14 of article 78: Expecting value: line 1 column 1 (char 0)
# 🔎 Processing chunk 16/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk15_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk15_graph.xlsx
# 📌 Concepts: 6 | Relations: 8
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk15_graph.png
# 🔎 Processing chunk 17/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk16_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk16_graph.xlsx
# 📌 Concepts: 20 | Relations: 16
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk16_graph.png
# 🔎 Processing chunk 18/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk17_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk17_graph.xlsx
# 📌 Concepts: 8 | Relations: 7
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk17_graph.png
# 🔎 Processing chunk 19/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk18_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk18_graph.xlsx
# 📌 Concepts: 13 | Relations: 15
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk18_graph.png
# 🔎 Processing chunk 20/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk19_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk19_graph.xlsx
# 📌 Concepts: 19 | Relations: 17
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk19_graph.png
# 🔎 Processing chunk 21/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk20_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk20_graph.xlsx
# 📌 Concepts: 13 | Relations: 12
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk20_graph.png
# 🔎 Processing chunk 22/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk21_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk21_graph.xlsx
# 📌 Concepts: 13 | Relations: 12
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk21_graph.png
# 🔎 Processing chunk 23/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk22_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk22_graph.xlsx
# 📌 Concepts: 7 | Relations: 4
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk22_graph.png
# 🔎 Processing chunk 24/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk23_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk23_graph.xlsx
# 📌 Concepts: 16 | Relations: 15
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk23_graph.png
# 🔎 Processing chunk 25/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk24_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk24_graph.xlsx
# 📌 Concepts: 13 | Relations: 13
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk24_graph.png
# 🔎 Processing chunk 26/26...
# ✅ Saved JSON to output5/04.29_KG__article78_chunk25_graph.json
# ✅ Saved Excel to output5/04.29_KG__article78_chunk25_graph.xlsx
# 📌 Concepts: 20 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article78_chunk25_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/8.txt
# 🧮 Text token count: 16351
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article8_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article8_chunk0_graph.xlsx
# 📌 Concepts: 21 | Relations: 20
# 🖼️ Saved graph visualization: output5/04.29_KG__article8_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article8_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article8_chunk1_graph.xlsx
# 📌 Concepts: 20 | Relations: 16
# 🖼️ Saved graph visualization: output5/04.29_KG__article8_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/85.txt
# 🧮 Text token count: 17654
# ⚡ Text too large: Splitting into chunks...
# 🔎 Processing chunk 1/2...
# ✅ Saved JSON to output5/04.29_KG__article85_chunk0_graph.json
# ✅ Saved Excel to output5/04.29_KG__article85_chunk0_graph.xlsx
# 📌 Concepts: 20 | Relations: 21
# 🖼️ Saved graph visualization: output5/04.29_KG__article85_chunk0_graph.png
# 🔎 Processing chunk 2/2...
# ✅ Saved JSON to output5/04.29_KG__article85_chunk1_graph.json
# ✅ Saved Excel to output5/04.29_KG__article85_chunk1_graph.xlsx
# 📌 Concepts: 20 | Relations: 15
# 🖼️ Saved graph visualization: output5/04.29_KG__article85_chunk1_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/86.txt
# 🧮 Text token count: 13660
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article86_graph.json
# ✅ Saved Excel to output5/04.29_KG__article86_graph.xlsx
# 📌 Concepts: 22 | Relations: 22
# 🖼️ Saved graph visualization: output5/04.29_KG__article86_chunk0_graph.png
# 📄 Loading and processing file: /Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text_try/97.txt
# 🧮 Text token count: 4506
# 🔎 Processing chunk 1/1...
# ✅ Saved JSON to output5/04.29_KG__article97_graph.json
# ✅ Saved Excel to output5/04.29_KG__article97_graph.xlsx
# 📌 Concepts: 17 | Relations: 16
# 🖼️ Saved graph visualization: output5/04.29_KG__article97_chunk0_graph.png
#
# 📦 Saving master file with 481 entries to output5/04.29_master_knowledge.json...
# ✅ Master JSON saved!

# %% [markdown]
# ## Analysis on files

# %%
import tiktoken
import os
import pandas as pd

def count_tokens_in_folder(folder_path, output_csv_path="output/corpus_token_counts.xlsx", model="gpt-3.5-turbo"):
    encoding = tiktoken.encoding_for_model(model)

    records = []

    txt_files = [f for f in os.listdir(folder_path) if f.endswith(".txt")]
    for file in txt_files:
        full_path = os.path.join(folder_path, file)
        with open(full_path, "r", encoding="utf-8") as f:
            text = f.read()
            tokens = len(encoding.encode(text))
            records.append({
                "File": file,
                "Tokens": tokens
            })

    df = pd.DataFrame(records)
    df.sort_values(by="Tokens", ascending=False, inplace=True)

    # Ensure output folder exists
    os.makedirs(os.path.dirname(output_csv_path), exist_ok=True)

    df.to_excel(output_csv_path, index=False)
    print(f"✅ Token count saved to {output_csv_path}")

    # Quick statistics
    print("\n📊 Token Statistics:")
    print(df.describe())

# Example Usage
count_tokens_in_folder("/Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/Corpus/main/text", output_csv_path="output_analysis/token_counts.xlsx")
# Out:
# ✅ Token count saved to output_analysis/token_counts.xlsx
#
# 📊 Token Statistics:
#               Tokens
# count     211.000000
# mean    23786.194313
# std     42158.720071
# min       490.000000
# 25%      5925.500000
# 50%     13376.000000
# 75%     20169.500000
# max    307247.000000

# %%
import pandas as pd
import os

def combine_excel_files(folder_path, output_excel_path="output/combined_articles.xlsx"):
    excel_files = [f for f in os.listdir(folder_path) if f.endswith(".xlsx")]

    all_dfs = []
    for file in excel_files:
        full_path = os.path.join(folder_path, file)
        print(f"🔎 Reading {file}...")
        try:
            df = pd.read_excel(full_path)
            article_no = os.path.splitext(file)[0].split("_article")[-1].split("_")[0]  # Extract article number
            df["Article File"] = file
            df["Article No"] = article_no
            all_dfs.append(df)
        except Exception as e:
            print(f"⚠️ Skipping {file}: {e}")

    combined_df = pd.concat(all_dfs, ignore_index=True)

    print(f"\n📊 Combined {len(all_dfs)} files into a single dataframe with {len(combined_df)} rows.")

    # Ensure output folder exists
    os.makedirs(os.path.dirname(output_excel_path), exist_ok=True)

    combined_df.to_excel(output_excel_path, index=False)
    print(f"✅ Combined Excel saved to {output_excel_path}")

    # Basic Initial Analysis
    print("\n🔎 Initial Analysis:")
    print(f"Total Relations: {len(combined_df)}")
    print(f"Unique Subjects: {combined_df['Subject'].nunique()}")
    print(f"Unique Objects: {combined_df['Object'].nunique()}")
    print(f"Top 10 Relations:\n{combined_df['Relation'].value_counts().head(10)}")

# Example Usage
combine_excel_files("output5", output_excel_path="output_analysis/combined_articles.xlsx")
# Out:
# 🔎 Reading 04.29_KG__article2_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article125_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article294_graph.xlsx...
# 🔎 Reading 04.29_KG__article10_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article28_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article4_graph.xlsx...
# 🔎 Reading 04.29_KG__article402_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article370_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article278_chunk4_graph.xlsx...
# 🔎 Reading 04.29_KG__article320_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article209_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article40_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article302_chunk4_graph.xlsx...
# 🔎 Reading 04.29_KG__article38_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article76_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article438_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article332_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article111_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk18_graph.xlsx...
# 🔎 Reading 04.29_KG__article373_chunk8_graph.xlsx...
# 🔎 Reading 04.29_KG__article183_graph.xlsx...
# 🔎 Reading 04.29_KG__article372_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article298_chunk18_graph.xlsx...
# 🔎 Reading 04.29_KG__article314_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article384_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article288_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article301_graph.xlsx...
# 🔎 Reading 04.29_KG__article376_chunk5_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk11_graph.xlsx...
# 🔎 Reading 04.29_KG__article139_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article20_chunk4_graph.xlsx...
# 🔎 Reading 04.29_KG__article73_graph.xlsx...
# 🔎 Reading 04.29_KG__article426_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article129_graph.xlsx...
# 🔎 Reading 04.29_KG__article354_graph.xlsx...
# 🔎 Reading 04.29_KG__article160_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article138_graph.xlsx...
# 🔎 Reading 04.29_KG__article410_graph.xlsx...
# 🔎 Reading 04.29_KG__article302_chunk9_graph.xlsx...
# 🔎 Reading 04.29_KG__article279_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article431_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article55_graph.xlsx...
# 🔎 Reading 04.29_KG__article278_chunk9_graph.xlsx...
# 🔎 Reading 04.29_KG__article85_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article365_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article108_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article421_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article196_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article49_graph.xlsx...
# 🔎 Reading 04.29_KG__article377_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article293_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article184_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article114_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article376_chunk8_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article351_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article298_chunk22_graph.xlsx...
# 🔎 Reading 04.29_KG__article47_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk22_graph.xlsx...
# 🔎 Reading 04.29_KG__article391_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk15_graph.xlsx...
# 🔎 Reading 04.29_KG__article265_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article373_chunk5_graph.xlsx...
# 🔎 Reading 04.29_KG__article285_graph.xlsx...
# 🔎 Reading 04.29_KG__article349_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article295_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article377_chunk13_graph.xlsx...
# 🔎 Reading 04.29_KG__article388_graph.xlsx...
# 🔎 Reading 04.29_KG__article51_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article233_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article50_graph.xlsx...
# 🔎 Reading 04.29_KG__article263_graph.xlsx...
# 🔎 Reading 04.29_KG__article321_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article67_graph.xlsx...
# 🔎 Reading 04.29_KG__article37_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk8_graph.xlsx...
# 🔎 Reading 04.29_KG__article361_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article32_graph.xlsx...
# 🔎 Reading 04.29_KG__article425_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article223_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article142_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article322_graph.xlsx...
# 🔎 Reading 04.29_KG__article110_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article180_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article395_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article373_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article298_chunk9_graph.xlsx...
# 🔎 Reading 04.29_KG__article369_chunk7_graph.xlsx...
# 🔎 Reading 04.29_KG__article394_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk10_graph.xlsx...
# 🔎 Reading 04.29_KG__article178_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article409_graph.xlsx...
# 🔎 Reading 04.29_KG__article377_chunk5_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk19_graph.xlsx...
# 🔎 Reading 04.29_KG__article176_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk4_graph.xlsx...
# 🔎 Reading 04.29_KG__article174_graph.xlsx...
# 🔎 Reading 04.29_KG__article355_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article427_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk5_graph.xlsx...
# 🔎 Reading 04.29_KG__article8_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article342_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article236_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article318_graph.xlsx...
# 🔎 Reading 04.29_KG__article278_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article152_graph.xlsx...
# 🔎 Reading 04.29_KG__article302_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article147_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article44_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article385_graph.xlsx...
# 🔎 Reading 04.29_KG__article72_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article280_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article149_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article1_graph.xlsx...
# 🔎 Reading 04.29_KG__article333_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk9_graph.xlsx...
# 🔎 Reading 04.29_KG__article179_graph.xlsx...
# 🔎 Reading 04.29_KG__article376_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk23_graph.xlsx...
# 🔎 Reading 04.29_KG__article384_chunk4_graph.xlsx...
# 🔎 Reading 04.29_KG__article14_graph.xlsx...
# 🔎 Reading 04.29_KG__article288_chunk7_graph.xlsx...
# 🔎 Reading 04.29_KG__article23_graph.xlsx...
# 🔎 Reading 04.29_KG__article404_graph.xlsx...
# 🔎 Reading 04.29_KG__article20_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article377_chunk8_graph.xlsx...
# 🔎 Reading 04.29_KG__article41_graph.xlsx...
# 🔎 Reading 04.29_KG__article272_graph.xlsx...
# 🔎 Reading 04.29_KG__article350_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article298_chunk4_graph.xlsx...
# 🔎 Reading 04.29_KG__article282_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article111_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article304_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article230_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article220_graph.xlsx...
# 🔎 Reading 04.29_KG__article288_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article314_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article384_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article24_graph.xlsx...
# 🔎 Reading 04.29_KG__article217_graph.xlsx...
# 🔎 Reading 04.29_KG__article376_chunk7_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk24_graph.xlsx...
# 🔎 Reading 04.29_KG__article286_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article216_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article20_chunk6_graph.xlsx...
# 🔎 Reading 04.29_KG__article362_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article426_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article278_chunk10_graph.xlsx...
# 🔎 Reading 04.29_KG__article10_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article382_graph.xlsx...
# 🔎 Reading 04.29_KG__article6_graph.xlsx...
# 🔎 Reading 04.29_KG__article402_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article28_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article370_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article262_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article328_graph.xlsx...
# 🔎 Reading 04.29_KG__article278_chunk6_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article40_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article222_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article137_graph.xlsx...
# 🔎 Reading 04.29_KG__article269_graph.xlsx...
# 🔎 Reading 04.29_KG__article356_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article302_chunk6_graph.xlsx...
# 🔎 Reading 04.29_KG__article19_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article377_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article439_graph.xlsx...
# 🔎 Reading 04.29_KG__article293_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article162_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article17_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article395_chunk5_graph.xlsx...
# 🔎 Reading 04.29_KG__article298_chunk20_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk17_graph.xlsx...
# 🔎 Reading 04.29_KG__article393_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk20_graph.xlsx...
# 🔎 Reading 04.29_KG__article373_chunk7_graph.xlsx...
# 🔎 Reading 04.29_KG__article369_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article347_graph.xlsx...
# 🔎 Reading 04.29_KG__article201_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article431_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article253_graph.xlsx...
# 🔎 Reading 04.29_KG__article158_graph.xlsx...
# 🔎 Reading 04.29_KG__article325_graph.xlsx...
# 🔎 Reading 04.29_KG__article116_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article223_chunk5_graph.xlsx...
# 🔎 Reading 04.29_KG__article227_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article365_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article196_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article377_chunk14_graph.xlsx...
# 🔎 Reading 04.29_KG__article130_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article298_chunk12_graph.xlsx...
# 🔎 Reading 04.29_KG__article13_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article395_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article86_graph.xlsx...
# 🔎 Reading 04.29_KG__article369_chunk5_graph.xlsx...
# 🔎 Reading 04.29_KG__article373_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk12_graph.xlsx...
# 🔎 Reading 04.29_KG__article396_graph.xlsx...
# 🔎 Reading 04.29_KG__article123_graph.xlsx...
# 🔎 Reading 04.29_KG__article323_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article429_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article377_chunk7_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk6_graph.xlsx...
# 🔎 Reading 04.29_KG__article176_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article427_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article228_graph.xlsx...
# 🔎 Reading 04.29_KG__article288_chunk8_graph.xlsx...
# 🔎 Reading 04.29_KG__article27_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article377_chunk11_graph.xlsx...
# 🔎 Reading 04.29_KG__article295_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article51_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article65_graph.xlsx...
# 🔎 Reading 04.29_KG__article321_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article261_graph.xlsx...
# 🔎 Reading 04.29_KG__article431_chunk4_graph.xlsx...
# 🔎 Reading 04.29_KG__article52_graph.xlsx...
# 🔎 Reading 04.29_KG__article420_graph.xlsx...
# 🔎 Reading 04.29_KG__article317_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article375_graph.xlsx...
# 🔎 Reading 04.29_KG__article142_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article223_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article357_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk21_graph.xlsx...
# 🔎 Reading 04.29_KG__article306_graph.xlsx...
# 🔎 Reading 04.29_KG__article18_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article376_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk16_graph.xlsx...
# 🔎 Reading 04.29_KG__article288_chunk5_graph.xlsx...
# 🔎 Reading 04.29_KG__article384_chunk6_graph.xlsx...
# 🔎 Reading 04.29_KG__article406_graph.xlsx...
# 🔎 Reading 04.29_KG__article364_graph.xlsx...
# 🔎 Reading 04.29_KG__article353_graph.xlsx...
# 🔎 Reading 04.29_KG__article58_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article20_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article282_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article350_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article366_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article422_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article145_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article105_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article326_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article342_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk7_graph.xlsx...
# 🔎 Reading 04.29_KG__article278_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article430_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article68_graph.xlsx...
# 🔎 Reading 04.29_KG__article302_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article334_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article268_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article44_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article278_chunk15_graph.xlsx...
# 🔎 Reading 04.29_KG__article97_graph.xlsx...
# 🔎 Reading 04.29_KG__article198_graph.xlsx...
# 🔎 Reading 04.29_KG__article402_chunk6_graph.xlsx...
# 🔎 Reading 04.29_KG__article431_chunk7_graph.xlsx...
# 🔎 Reading 04.29_KG__article255_graph.xlsx...
# 🔎 Reading 04.29_KG__article37_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article33_graph.xlsx...
# 🔎 Reading 04.29_KG__article361_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk9_graph.xlsx...
# 🔎 Reading 04.29_KG__article142_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article223_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article237_graph.xlsx...
# 🔎 Reading 04.29_KG__article425_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article349_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article402_chunk8_graph.xlsx...
# 🔎 Reading 04.29_KG__article377_chunk12_graph.xlsx...
# 🔎 Reading 04.29_KG__article295_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article389_graph.xlsx...
# 🔎 Reading 04.29_KG__article233_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article51_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article120_graph.xlsx...
# 🔎 Reading 04.29_KG__article178_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article117_graph.xlsx...
# 🔎 Reading 04.29_KG__article408_graph.xlsx...
# 🔎 Reading 04.29_KG__article377_chunk4_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk5_graph.xlsx...
# 🔎 Reading 04.29_KG__article176_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk18_graph.xlsx...
# 🔎 Reading 04.29_KG__article355_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article180_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article110_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article298_chunk11_graph.xlsx...
# 🔎 Reading 04.29_KG__article395_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article281_graph.xlsx...
# 🔎 Reading 04.29_KG__article298_chunk8_graph.xlsx...
# 🔎 Reading 04.29_KG__article373_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk11_graph.xlsx...
# 🔎 Reading 04.29_KG__article44_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article147_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article278_chunk16_graph.xlsx...
# 🔎 Reading 04.29_KG__article280_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article290_graph.xlsx...
# 🔎 Reading 04.29_KG__article72_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article149_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article402_chunk5_graph.xlsx...
# 🔎 Reading 04.29_KG__article342_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article8_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk4_graph.xlsx...
# 🔎 Reading 04.29_KG__article430_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article319_graph.xlsx...
# 🔎 Reading 04.29_KG__article236_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article278_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article302_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article131_graph.xlsx...
# 🔎 Reading 04.29_KG__article350_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article282_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article187_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk8_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk15_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk22_graph.xlsx...
# 🔎 Reading 04.29_KG__article376_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article288_chunk6_graph.xlsx...
# 🔎 Reading 04.29_KG__article384_chunk5_graph.xlsx...
# 🔎 Reading 04.29_KG__article367_graph.xlsx...
# 🔎 Reading 04.29_KG__article20_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article273_graph.xlsx...
# 🔎 Reading 04.29_KG__article377_chunk9_graph.xlsx...
# 🔎 Reading 04.29_KG__article320_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article278_chunk5_graph.xlsx...
# 🔎 Reading 04.29_KG__article262_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article342_chunk4_graph.xlsx...
# 🔎 Reading 04.29_KG__article40_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article134_graph.xlsx...
# 🔎 Reading 04.29_KG__article103_graph.xlsx...
# 🔎 Reading 04.29_KG__article38_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article302_chunk5_graph.xlsx...
# 🔎 Reading 04.29_KG__article76_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article125_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article2_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article381_graph.xlsx...
# 🔎 Reading 04.29_KG__article10_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article402_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article288_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article384_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article314_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk10_graph.xlsx...
# 🔎 Reading 04.29_KG__article139_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article276_graph.xlsx...
# 🔎 Reading 04.29_KG__article45_graph.xlsx...
# 🔎 Reading 04.29_KG__article20_chunk5_graph.xlsx...
# 🔎 Reading 04.29_KG__article426_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article332_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article438_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk19_graph.xlsx...
# 🔎 Reading 04.29_KG__article111_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article298_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article230_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article372_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article108_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article365_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article421_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article302_chunk10_graph.xlsx...
# 🔎 Reading 04.29_KG__article196_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article201_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article160_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article411_graph.xlsx...
# 🔎 Reading 04.29_KG__article279_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article54_graph.xlsx...
# 🔎 Reading 04.29_KG__article431_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article278_chunk8_graph.xlsx...
# 🔎 Reading 04.29_KG__article223_chunk6_graph.xlsx...
# 🔎 Reading 04.29_KG__article85_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article205_graph.xlsx...
# 🔎 Reading 04.29_KG__article351_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article298_chunk23_graph.xlsx...
# 🔎 Reading 04.29_KG__article298_chunk14_graph.xlsx...
# 🔎 Reading 04.29_KG__article47_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk23_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk14_graph.xlsx...
# 🔎 Reading 04.29_KG__article390_graph.xlsx...
# 🔎 Reading 04.29_KG__article265_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article369_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article373_chunk4_graph.xlsx...
# 🔎 Reading 04.29_KG__article377_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article293_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article114_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article184_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article170_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article122_graph.xlsx...
# 🔎 Reading 04.29_KG__article178_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article377_chunk6_graph.xlsx...
# 🔎 Reading 04.29_KG__article429_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article323_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk7_graph.xlsx...
# 🔎 Reading 04.29_KG__article427_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article298_chunk24_graph.xlsx...
# 🔎 Reading 04.29_KG__article298_chunk13_graph.xlsx...
# 🔎 Reading 04.29_KG__article13_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article395_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article369_chunk4_graph.xlsx...
# 🔎 Reading 04.29_KG__article373_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk24_graph.xlsx...
# 🔎 Reading 04.29_KG__article397_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk13_graph.xlsx...
# 🔎 Reading 04.29_KG__article431_chunk5_graph.xlsx...
# 🔎 Reading 04.29_KG__article343_graph.xlsx...
# 🔎 Reading 04.29_KG__article317_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article416_graph.xlsx...
# 🔎 Reading 04.29_KG__article223_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article31_graph.xlsx...
# 🔎 Reading 04.29_KG__article357_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article295_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article377_chunk10_graph.xlsx...
# 🔎 Reading 04.29_KG__article282_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article350_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article298_chunk7_graph.xlsx...
# 🔎 Reading 04.29_KG__article366_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article145_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article422_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article105_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article185_graph.xlsx...
# 🔎 Reading 04.29_KG__article326_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article376_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article18_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk20_graph.xlsx...
# 🔎 Reading 04.29_KG__article330_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk17_graph.xlsx...
# 🔎 Reading 04.29_KG__article288_chunk4_graph.xlsx...
# 🔎 Reading 04.29_KG__article58_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article352_graph.xlsx...
# 🔎 Reading 04.29_KG__article271_graph.xlsx...
# 🔎 Reading 04.29_KG__article246_graph.xlsx...
# 🔎 Reading 04.29_KG__article20_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article75_graph.xlsx...
# 🔎 Reading 04.29_KG__article268_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article44_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article278_chunk14_graph.xlsx...
# 🔎 Reading 04.29_KG__article199_graph.xlsx...
# 🔎 Reading 04.29_KG__article402_chunk7_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk6_graph.xlsx...
# 🔎 Reading 04.29_KG__article342_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article278_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article166_graph.xlsx...
# 🔎 Reading 04.29_KG__article430_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article302_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article334_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article12_graph.xlsx...
# 🔎 Reading 04.29_KG__article384_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article288_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article335_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk12_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk25_graph.xlsx...
# 🔎 Reading 04.29_KG__article376_chunk6_graph.xlsx...
# 🔎 Reading 04.29_KG__article216_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article286_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article362_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article426_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article304_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article230_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article163_graph.xlsx...
# 🔎 Reading 04.29_KG__article262_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article278_chunk7_graph.xlsx...
# 🔎 Reading 04.29_KG__article78_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article101_graph.xlsx...
# 🔎 Reading 04.29_KG__article222_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article40_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article76_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article302_chunk7_graph.xlsx...
# 🔎 Reading 04.29_KG__article356_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article38_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article278_chunk11_graph.xlsx...
# 🔎 Reading 04.29_KG__article297_graph.xlsx...
# 🔎 Reading 04.29_KG__article10_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article402_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article28_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article370_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article395_chunk4_graph.xlsx...
# 🔎 Reading 04.29_KG__article298_chunk21_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk16_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk21_graph.xlsx...
# 🔎 Reading 04.29_KG__article373_chunk6_graph.xlsx...
# 🔎 Reading 04.29_KG__article369_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article377_chunk3_graph.xlsx...
# 🔎 Reading 04.29_KG__article19_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article127_graph.xlsx...
# 🔎 Reading 04.29_KG__article162_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article17_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article338_graph.xlsx...
# 🔎 Reading 04.29_KG__article21_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article227_chunk1_graph.xlsx...
# 🔎 Reading 04.29_KG__article365_chunk2_graph.xlsx...
# 🔎 Reading 04.29_KG__article130_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article295_chunk4_graph.xlsx...
# 🔎 Reading 04.29_KG__article377_chunk15_graph.xlsx...
# 🔎 Reading 04.29_KG__article413_graph.xlsx...
# 🔎 Reading 04.29_KG__article431_chunk0_graph.xlsx...
# 🔎 Reading 04.29_KG__article252_graph.xlsx...
# 🔎 Reading 04.29_KG__article223_chunk4_graph.xlsx...
# 🔎 Reading 04.29_KG__article116_chunk1_graph.xlsx...
#
# 📊 Combined 494 files into a single dataframe with 7198 rows.
# ✅ Combined Excel saved to output_analysis/combined_articles.xlsx
#
# 🔎 Initial Analysis:
# Total Relations: 7198
# Unique Subjects: 3509
# Unique Objects: 5376
# Top 10 Relations:
# Relation
# supports          193
# provides          183
# enables           148
# involves          145
# includes          118
# include           105
# facilitates        99
# requires           98
# support            94
# participate in     89
# Name: count, dtype: int64

# %%
import pandas as pd
import os

def analyze_combined_excel(combined_excel_path):
    # Load your combined Excel file
    df = pd.read_excel(combined_excel_path)
    print(f"✅ Loaded {len(df)} relations from {combined_excel_path}")

    # 1. Total Relations per Article
    relations_per_article = df.groupby("Article No").size().reset_index(name="Total_Relations")
    print("\n🔗 Total relations per article:")
    print(relations_per_article.head())

    # 2. Since we don't have chunk info, assume 1 chunk per file (optional)
    relations_per_article["Estimated_Num_Chunks"] = 1

    # 3. Save the summary
    output_folder = os.path.dirname(combined_excel_path)
    os.makedirs(output_folder, exist_ok=True)

    relations_per_article.to_excel(os.path.join(output_folder, "analysis_summary_per_article.xlsx"), index=False)
    print(f"\n✅ Summary analysis saved to {os.path.join(output_folder, 'analysis_summary_per_article.xlsx')}")

    return relations_per_article

# Example usage:
summary_per_article = analyze_combined_excel("output_analysis/combined_articles.xlsx")
# Out:
# ✅ Loaded 7198 relations from output_analysis/combined_articles.xlsx
#
# 🔗 Total relations per article:
#    Article No  Total_Relations
# 0           1               19
# 1           2               21
# 2           4               20
# 3           6               16
# 4           8               36
#
# ✅ Summary analysis saved to output_analysis/analysis_summary_per_article.xlsx

# %%
import pandas as pd
import numpy as np
import os

def analyze_combined_excel_detailed(combined_excel_path):
    # Load your combined Excel file
    df = pd.read_excel(combined_excel_path)
    print(f"✅ Loaded {len(df)} relations from {combined_excel_path}")

    # Group by Article No
    relations_per_article = df.groupby("Article No").size().reset_index(name="Total_Relations")
    print("\n🔗 Total relations per article (first 5):")
    print(relations_per_article.head())

    # Basic Statistics
    total_articles = len(relations_per_article)
    avg_relations = relations_per_article["Total_Relations"].mean()
    median_relations = relations_per_article["Total_Relations"].median()
    min_relations = relations_per_article["Total_Relations"].min()
    max_relations = relations_per_article["Total_Relations"].max()
    std_relations = relations_per_article["Total_Relations"].std()

    print(f"\n📈 Basic Statistics:")
    print(f"- Total Articles: {total_articles}")
    print(f"- Mean Total Relations: {avg_relations:.2f}")
    print(f"- Median Total Relations: {median_relations}")
    print(f"- Min Relations: {min_relations}")
    print(f"- Max Relations: {max_relations}")
    print(f"- Standard Deviation: {std_relations:.2f}")

    # Outlier Detection (using IQR method)
    Q1 = relations_per_article["Total_Relations"].quantile(0.25)
    Q3 = relations_per_article["Total_Relations"].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    print(f"\n🛡️ Outlier Thresholds:")
    print(f"- Lower Bound: {lower_bound}")
    print(f"- Upper Bound: {upper_bound}")

    # Identify outliers
    outliers = relations_per_article[
        (relations_per_article["Total_Relations"] < lower_bound) | 
        (relations_per_article["Total_Relations"] > upper_bound)
    ]
    non_outliers = relations_per_article[
        (relations_per_article["Total_Relations"] >= lower_bound) & 
        (relations_per_article["Total_Relations"] <= upper_bound)
    ]

    print(f"\n🚨 Found {len(outliers)} outlier articles.")
    
    # Average without outliers
    avg_without_outliers = non_outliers["Total_Relations"].mean()
    median_without_outliers = non_outliers["Total_Relations"].median()

    print(f"\n📉 Statistics Excluding Outliers:")
    print(f"- Mean (no outliers): {avg_without_outliers:.2f}")
    print(f"- Median (no outliers): {median_without_outliers}")

    # Save detailed summary
    output_folder = os.path.dirname(combined_excel_path)
    os.makedirs(output_folder, exist_ok=True)

    relations_per_article.to_excel(os.path.join(output_folder, "analysis_summary_full.xlsx"), index=False)
    outliers.to_excel(os.path.join(output_folder, "analysis_outliers.xlsx"), index=False)
    non_outliers.to_excel(os.path.join(output_folder, "analysis_no_outliers.xlsx"), index=False)
    
    print(f"\n✅ Analysis files saved to {output_folder}!")

    return {
        "total_articles": total_articles,
        "avg_relations": avg_relations,
        "median_relations": median_relations,
        "std_relations": std_relations,
        "avg_without_outliers": avg_without_outliers,
        "median_without_outliers": median_without_outliers,
        "num_outliers": len(outliers)
    }

# Example usage
summary_stats = analyze_combined_excel_detailed("output_analysis/combined_articles.xlsx")
# Out:
# ✅ Loaded 7198 relations from output_analysis/combined_articles.xlsx
#
# 🔗 Total relations per article (first 5):
#    Article No  Total_Relations
# 0           1               19
# 1           2               21
# 2           4               20
# 3           6               16
# 4           8               36
#
# 📈 Basic Statistics:
# - Total Articles: 211
# - Mean Total Relations: 34.11
# - Median Total Relations: 21.0
# - Min Relations: 9
# - Max Relations: 302
# - Standard Deviation: 36.04
#
# 🛡️ Outlier Thresholds:
# - Lower Bound: -9.0
# - Upper Bound: 63.0
#
# 🚨 Found 18 outlier articles.
#
# 📉 Statistics Excluding Outliers:
# - Mean (no outliers): 25.70
# - Median (no outliers): 20.0
#
# ✅ Analysis files saved to output_analysis!

# %%
import pandas as pd
import os
import re

def clean_and_group_relations(excel_path):
    # Load your combined relations
    df = pd.read_excel(excel_path)
    print(f"✅ Loaded {len(df)} rows from {excel_path}")

    # 1. Clean Relation column
    def clean_relation(rel):
        if isinstance(rel, str):
            rel = rel.strip()
            if rel.endswith("s") and len(rel) > 3:  # avoid words like "is" becoming "i"
                return rel[:-1]
            else:
                return rel
        return rel

    df["Relation_Clean"] = df["Relation"].apply(clean_relation)
    print(f"🧹 Cleaned relation verbs (singularized).")

    # 2. Group by Subject, Relation_Clean, Object
    grouped = df.groupby(["Subject", "Relation_Clean", "Object", "Article No"]).size().reset_index(name="Count")
    print(f"📦 Grouped into {len(grouped)} unique (Subject, Relation, Object, Article) combinations.")

    # Save grouped version
    output_folder = os.path.dirname(excel_path)
    os.makedirs(output_folder, exist_ok=True)

    grouped_output_path = os.path.join(output_folder, "cleaned_grouped_relations.xlsx")
    grouped.to_excel(grouped_output_path, index=False)
    print(f"✅ Saved grouped clean relations to {grouped_output_path}")

    # 3. Combine Subject and Object into one Entity column
    df_combined = pd.DataFrame()
    df_combined["Entity"] = df["Subject"].astype(str) + " -> " + df["Object"].astype(str)
    df_combined["Relation_Clean"] = df["Relation_Clean"]
    df_combined["Article No"] = df["Article No"]

    combined_output_path = os.path.join(output_folder, "combined_subject_object.xlsx")
    df_combined.to_excel(combined_output_path, index=False)
    print(f"✅ Saved combined (Subject-Object) to {combined_output_path}")

    return grouped, df_combined

# Example Usage
grouped_data, combined_entities = clean_and_group_relations("output_analysis/combined_articles.xlsx")
# Out:
# ✅ Loaded 7198 rows from output_analysis/combined_articles.xlsx
# 🧹 Cleaned relation verbs (singularized).
# 📦 Grouped into 7135 unique (Subject, Relation, Object, Article) combinations.
# ✅ Saved grouped clean relations to output_analysis/cleaned_grouped_relations.xlsx
# ✅ Saved combined (Subject-Object) to output_analysis/combined_subject_object.xlsx

# %% [markdown]
# # Level 2 Knowledge Graph HTML

# %%
import pandas as pd
from pyvis.network import Network
import collections
import networkx as nx
from networkx.algorithms import community

# --- 1. LOAD AND PREPARE THE DATA ---
print("Loading and preparing data...")
try:
    df = pd.read_csv('relations_final_entities.csv')
except FileNotFoundError:
    print("Error: 'relations_final_entities.csv' not found.")
    print("Please make sure the CSV file is in the same directory as this script.")
    exit()

# Clean up whitespace from all label columns
for col in ['subject_Label1', 'object_Label1', 'subject_Label2', 'object_Label2', 'relation']:
    if col in df.columns:
        df[col] = df[col].str.strip()

# Apply the filter based on Label1
filtered_df = df[
    (df['subject_Label1'] != 'Unlabeled') | (df['object_Label1'] != 'Unlabeled')
].copy()

# Drop any rows where the Label2 columns (our nodes) are missing
filtered_df.dropna(subset=['subject_Label2', 'object_Label2'], inplace=True)
print(f"Filtered down to {len(filtered_df)} valid relations for the full corpus.")


# --- 2. PROCESS NODES AND EDGES FOR THE ENTIRE CORPUS ---
node_to_group = {}
in_degree = collections.defaultdict(int)
edge_counts = collections.defaultdict(int)
edge_relations = collections.defaultdict(list)

for _, row in filtered_df.iterrows():
    source_node = row['subject_Label2']
    target_node = row['object_Label2']
    relation = row['relation']
    
    if source_node not in node_to_group:
        node_to_group[source_node] = row['subject_Label1']
    if target_node not in node_to_group:
        node_to_group[target_node] = row['object_Label1']
    
    in_degree[target_node] += 1
    
    edge = (source_node, target_node)
    edge_counts[edge] += 1
    edge_relations[edge].append(relation)


# --- 3. ADVANCED NETWORK ANALYSIS WITH NETWORKX ---
# Re-adding analysis to get community data for the dropdown
print("\n--- Starting Network Analysis for Community Detection ---")
G = nx.DiGraph()
for (source, target), count in edge_counts.items():
    G.add_edge(source, target, weight=count)

communities = community.louvain_communities(G.to_undirected(), weight='weight', seed=123)
node_to_community = {}
for i, comm in enumerate(communities):
    for node in comm:
        node_to_community[node] = i
print(f"Detected {len(communities)} communities/clusters in the network.")


# --- 4. CREATE CUSTOM COLOR MAP ---
defined_color_map = {
    'Economy': '#1f77b4', 'Ecosystem': '#ff7f0e', 'Events': '#2ca02c', 
    'Fields and Disciplines': '#d62728', 'Frameworks': '#9467bd', 'Institutional Action': '#8c564b',
    'Open Access': '#e377c2', 'Open Data': '#7f7f7f', 'Open Government': '#bcbd22',
    'Open Innovation': '#17becf', 'Open Science': '#aec7e8', 'Policies': '#ffbb78',
    'Research Outputs / Resources': '#98df8a', 'Research Processes / Practices': '#ff9896',
    'Research Values / Virtues': '#c5b0d5', 'Science and Society': '#c49c94',
    'Sociotechnical Devices': '#f7b6d2', 'Stakeholders/Actors': '#c7c7c7'
}
pastel_fallback = ['#A1C9F4', '#DEBB9B', '#B9F2F0', '#FFFEA3']
fallback_idx = 0
unique_groups = sorted(list(set(node_to_group.values())))
color_map = {}
for group in unique_groups:
    if group in defined_color_map:
        color_map[group] = defined_color_map[group]
    else:
        color_map[group] = pastel_fallback[fallback_idx % len(pastel_fallback)]
        fallback_idx += 1


# --- 5. CREATE THE PYVIS NETWORK ---
net = Network(height='100vh', width='100%', bgcolor='white', font_color='#222222', directed=True, notebook=True)
# Updated options for better performance and new styling
net.set_options("""
const options = {
  "configure": { "enabled": true, "filter": "physics" },
  "nodes": {
    "font": { "size": 22, "strokeWidth": 1, "strokeColor": "white" }
  },
  "edges": {
    "color": {
      "color": "#cccccc",
      "highlight": "#9370DB",
      "hover": "#9370DB",
      "inherit": false
    },
    "font": { "size": 12, "align": "top", "strokeWidth": 0 },
    "smooth": { "enabled": true, "type": "dynamic" }
  },
  "physics": {
    "enabled": true,
    "stabilization": {
      "enabled": true,
      "iterations": 1000,
      "updateInterval": 50,
      "onlyDynamicEdges": false,
      "fit": true
    },
    "barnesHut": {
      "gravitationalConstant": -40000,
      "centralGravity": 0.1,
      "springLength": 250
    },
    "minVelocity": 0.75
  },
  "interaction": { "hover": true, "navigationButtons": true }
}
""")


# --- 6. ADD NODES AND EDGES TO THE GRAPH ---
print("\nBuilding the interactive graph...")
# Add nodes with custom colors and community data
for node, group in node_to_group.items():
    node_size = 30 + (in_degree.get(node, 0) * 4)
    node_color = color_map.get(group, '#97c2fc')
    community_id = node_to_community.get(node, -1)
    
    tooltip = f"Category: {group}<br>Community ID: {community_id}"
    
    # Add community ID as a hidden attribute and explicitly set shape
    net.add_node(
        node, 
        label=node, 
        color=node_color, 
        value=node_size, 
        title=tooltip, 
        community=community_id,
        shape='box'  
    )

# Add aggregated edges with weights
for (source, target), count in edge_counts.items():
    unique_relations = sorted(list(set(edge_relations[(source, target)])))
    title_text = f"Frequency: {count}<br>Relations: {', '.join(unique_relations)}"
    net.add_edge(source=source, to=target, value=count, title=title_text)


# --- 7. GENERATE THE HTML FILE AND INJECT LEGEND AND DROPDOWN ---
output_filename = '/Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/P5_gephi/html_web/knowledge_graph.html'
try:
    net.save_graph(output_filename)
    
    # --- Create HTML for the legend ---
    legend_html = '<div id="legend"><h4>Categories</h4><ul>'
    for group in unique_groups:
        color = color_map.get(group)
        legend_html += f'<li><span style="background-color:{color};"></span>{group}</li>'
    legend_html += '</ul></div>'
    
    # --- Create HTML for the community dropdown ---
    dropdown_html = '<div id="community-filter"><span>Filter by Community: </span><select id="community-select">'
    dropdown_html += '<option value="all">Show All</option>'
    for i in range(len(communities)):
        dropdown_html += f'<option value="{i}">Community {i}</option>'
    dropdown_html += '</select></div>'

    # --- Create JavaScript for the filtering logic and to disable physics after load ---
    filter_script = """
    <script type="text/javascript">
      // Wait for the network to be fully initialized and stabilized
      network.on("stabilizationIterationsDone", function () {
        // Turn off physics to improve performance
        network.setOptions( { physics: false } );
        
        // Store original nodes and edges
        const allNodes = network.body.data.nodes.get();
        const allEdges = network.body.data.edges.get();
        const communitySelect = document.getElementById('community-select');

        communitySelect.addEventListener('change', (event) => {
          const selectedCommunity = event.target.value;
          
          let nodesToShow;
          if (selectedCommunity === 'all') {
            nodesToShow = allNodes;
          } else {
            nodesToShow = allNodes.filter(node => node.community == selectedCommunity);
          }
          
          // Create a new DataSet with the filtered nodes
          const filteredNodes = new vis.DataSet(nodesToShow);
          const nodeIdsToShow = new Set(filteredNodes.getIds());

          // Filter edges to only include those within the community
          const filteredEdges = new vis.DataSet(
            allEdges.filter(edge => nodeIdsToShow.has(edge.from) && nodeIdsToShow.has(edge.to))
          );
          
          // Update the network with the new data
          network.setData({nodes: filteredNodes, edges: filteredEdges});
        });
      });
    </script>
    """

    # --- Create CSS for all UI elements ---
    ui_css = """
    <style type='text/css'>
      #legend, #community-filter {
        position: absolute;
        background-color: rgba(255, 255, 255, 0.9);
        padding: 10px;
        border-radius: 6px;
        border: 1px solid #ccc;
        font-family: sans-serif;
        font-size: 14px;
        z-index: 1000;
      }
      #legend { bottom: 15px; left: 15px; max-height: 80vh; overflow-y: auto; }
      #community-filter { top: 15px; left: 15px; }
      #legend h4 { margin-top: 0; margin-bottom: 10px; }
      #legend ul { list-style: none; padding: 0; margin: 0; }
      #legend li { display: flex; align-items: center; margin-bottom: 5px; }
      #legend span {
        display: inline-block; width: 14px; height: 14px;
        margin-right: 8px; border-radius: 2px; border: 1px solid #555;
      }
    </style>
    """

    # --- Read the generated HTML, inject everything, and save ---
    with open(output_filename, 'r', encoding='utf-8') as f:
        html_content = f.read()
    
    html_content = html_content.replace('</head>', f'{ui_css}</head>')
    # Inject the dropdown and legend first, then the script
    html_content = html_content.replace('</body>', f'{legend_html}{dropdown_html}{filter_script}</body>')

    with open(output_filename, 'w', encoding='utf-8') as f:
        f.write(html_content)

    print(f"\n✅ Success! Interactive graph with legend and filter saved as '{output_filename}'")
    print("Open this file in your web browser to view the focused knowledge graph.")

except Exception as e:
    print(f"\nAn error occurred while saving the file: {e}")

# %% [markdown]
# ## Level 2 Knowledge Graph Analysis

# %%
import pandas as pd
import networkx as nx
from networkx.algorithms import community

# --- 1. LOAD AND PREPARE THE DATA ---
print("Loading and preparing data...")
try:
    df = pd.read_csv('relations_final_entities.csv')
except FileNotFoundError:
    print("Error: 'relations_final_entities.csv' not found.")
    print("Please make sure the CSV file is in the same directory as this script.")
    exit()

# Clean up whitespace from all label columns
for col in ['subject_Label1', 'object_Label1', 'subject_Label2', 'object_Label2', 'relation']:
    if col in df.columns:
        df[col] = df[col].str.strip()

# Apply the filter based on Label1
filtered_df = df[
    (df['subject_Label1'] != 'Unlabeled') | (df['object_Label1'] != 'Unlabeled')
].copy()

# Drop any rows where the Label2 columns (our nodes) are missing
filtered_df.dropna(subset=['subject_Label2', 'object_Label2'], inplace=True)
print(f"Filtered down to {len(filtered_df)} valid relations for the full corpus.")


# --- 2. PROCESS NODES AND EDGES FOR THE ENTIRE CORPUS ---
edge_counts = {}
for _, row in filtered_df.iterrows():
    source_node = row['subject_Label2']
    target_node = row['object_Label2']
    
    edge = (source_node, target_node)
    edge_counts[edge] = edge_counts.get(edge, 0) + 1


# --- 3. ADVANCED NETWORK ANALYSIS WITH NETWORKX ---
print("\n--- Starting Advanced Network Analysis ---")
# Create a NetworkX graph to perform calculations
G = nx.DiGraph()
for (source, target), count in edge_counts.items():
    G.add_edge(source, target, weight=count)

# --- A. Overall Network Statistics ---
density = nx.density(G)
num_nodes = G.number_of_nodes()
num_edges = G.number_of_edges()
avg_degree = sum(dict(G.degree()).values()) / num_nodes
print("\n--- Overall Network Statistics ---")
print(f"Total Nodes: {num_nodes}")
print(f"Total Edges: {num_edges}")
print(f"Network Density: {density:.4f}")
print(f"Average Degree: {avg_degree:.4f}")


# --- B. Global Centrality Measures ---
print("\n--- Global Centrality Analysis ---")
# Degree Centrality (In-degree and Out-degree)
in_degree_centrality = nx.in_degree_centrality(G)
out_degree_centrality = nx.out_degree_centrality(G)
betweenness = nx.betweenness_centrality(G, weight='weight', normalized=True)

print("\nTop 5 Nodes by In-Degree (Most Referenced):")
for node, score in sorted(in_degree_centrality.items(), key=lambda item: item[1], reverse=True)[:5]:
    print(f"  - {node}: {score:.4f}")

print("\nTop 5 Nodes by Out-Degree (Most Referential):")
for node, score in sorted(out_degree_centrality.items(), key=lambda item: item[1], reverse=True)[:5]:
    print(f"  - {node}: {score:.4f}")

print("\nTop 5 Most Influential Nodes (Global Betweenness Centrality):")
for node, score in sorted(betweenness.items(), key=lambda item: item[1], reverse=True)[:5]:
    print(f"  - {node}: {score:.4f}")

# --- C. Community Detection ---
print("\n--- Community Detection ---")
# Use the Louvain method on an undirected version of the graph to find communities
communities = community.louvain_communities(G.to_undirected(), weight='weight', seed=123)
# Create a mapping from node to its community ID
node_to_community = {}
for i, comm in enumerate(communities):
    for node in comm:
        node_to_community[node] = i
print(f"Detected {len(communities)} communities/clusters in the network.")

# --- D. RANK NODES WITHIN EACH COMMUNITY ---
print("\n--- Ranking Nodes Within Each Community (by Intra-Community Centrality) ---")
for i, comm_nodes in enumerate(sorted(communities, key=len, reverse=True)):
    # Create a subgraph containing only the nodes and edges of this community
    subgraph = G.subgraph(comm_nodes)
    
    # Calculate Betweenness Centrality *within* this specific subgraph
    # This measures a node's importance relative to its own community
    community_centrality = nx.betweenness_centrality(subgraph, weight='weight', normalized=True)
    
    # Sort the nodes in this community by their local centrality score
    sorted_community_nodes = sorted(community_centrality.items(), key=lambda item: item[1], reverse=True)
    
    print(f"\n- Community {i} ({len(comm_nodes)} members):")
    # Print the top 3 most central nodes for this community
    for node, score in sorted_community_nodes[:10]:
        print(f"  - {node} (Local Centrality: {score:.4f})")
    if len(sorted_community_nodes) > 3:
        print("  - ...")
# Out:
# Loading and preparing data...
# Filtered down to 1067 valid relations for the full corpus.
#
# --- Starting Advanced Network Analysis ---
#
# --- Overall Network Statistics ---
# Total Nodes: 146
# Total Edges: 706
# Network Density: 0.0333
# Average Degree: 9.6712
#
# --- Global Centrality Analysis ---
#
# Top 5 Nodes by In-Degree (Most Referenced):
#   - open access: 0.2621
#   - sharing: 0.2069
#   - open science: 0.1724
#   - data: 0.1724
#   - repository: 0.1448
#
# Top 5 Nodes by Out-Degree (Most Referential):
#   - open science: 0.4138
#   - open access: 0.2000
#   - researcher: 0.2000
#   - repository: 0.1862
#   - data: 0.1724
#
# Top 5 Most Influential Nodes (Global Betweenness Centrality):
#   - open science: 0.1429
#   - open access: 0.1203
#   - sharing: 0.1050
#   - data: 0.0941
#   - ecosystem: 0.0671
#
# --- Community Detection ---
# Detected 7 communities/clusters in the network.
#
# --- Ranking Nodes Within Each Community (by Intra-Community Centrality) ---
#
# - Community 0 (31 members):
#   - research output (Local Centrality: 0.1857)
#   - infrastructure (Local Centrality: 0.1816)
#   - sharing (Local Centrality: 0.1791)
#   - repository (Local Centrality: 0.1600)
#   - tools (Local Centrality: 0.0601)
#   - platform (Local Centrality: 0.0531)
#   - preprint (Local Centrality: 0.0411)
#   - cloud (Local Centrality: 0.0230)
#   - publishers (Local Centrality: 0.0185)
#   - software (Local Centrality: 0.0178)
#   - ...
#
# - Community 1 (26 members):
#   - open access (Local Centrality: 0.1922)
#   - peer review (Local Centrality: 0.1139)
#   - integrity (Local Centrality: 0.0467)
#   - communication (Local Centrality: 0.0406)
#   - apc (Local Centrality: 0.0400)
#   - agreements (Local Centrality: 0.0358)
#   - journal (Local Centrality: 0.0353)
#   - evaluating (Local Centrality: 0.0317)
#   - funders (Local Centrality: 0.0242)
#   - control (Local Centrality: 0.0208)
#   - ...
#
# - Community 2 (22 members):
#   - data (Local Centrality: 0.2740)
#   - standards (Local Centrality: 0.2131)
#   - data practices (Local Centrality: 0.1347)
#   - quality (Local Centrality: 0.0903)
#   - curation (Local Centrality: 0.0889)
#   - management (Local Centrality: 0.0869)
#   - metadata (Local Centrality: 0.0762)
#   - accessibility (Local Centrality: 0.0690)
#   - data management (Local Centrality: 0.0546)
#   - fair (Local Centrality: 0.0377)
#   - ...
#
# - Community 3 (21 members):
#   - policies (Local Centrality: 0.0360)
#   - open science (Local Centrality: 0.0263)
#   - institutions (Local Centrality: 0.0105)
#   - governance (Local Centrality: 0.0079)
#   - trust (Local Centrality: 0.0075)
#   - researcher (Local Centrality: 0.0061)
#   - ethics (Local Centrality: 0.0035)
#   - license (Local Centrality: 0.0000)
#   - resource (Local Centrality: 0.0000)
#   - social justice (Local Centrality: 0.0000)
#   - ...
#
# - Community 4 (18 members):
#   - ecosystem (Local Centrality: 0.1765)
#   - machine learning (Local Centrality: 0.0625)
#   - digital transformation (Local Centrality: 0.0478)
#   - technology (Local Centrality: 0.0221)
#   - business (Local Centrality: 0.0000)
#   - value (Local Centrality: 0.0000)
#   - ai (Local Centrality: 0.0000)
#   - innovation (Local Centrality: 0.0000)
#   - science (Local Centrality: 0.0000)
#   - growth (Local Centrality: 0.0000)
#   - ...
#
# - Community 5 (15 members):
#   - funding (Local Centrality: 0.0769)
#   - universities (Local Centrality: 0.0440)
#   - multilingualism (Local Centrality: 0.0055)
#   - stakeholder (Local Centrality: 0.0000)
#   - impact (Local Centrality: 0.0000)
#   - intermediaries (Local Centrality: 0.0000)
#   - metric (Local Centrality: 0.0000)
#   - services (Local Centrality: 0.0000)
#   - project (Local Centrality: 0.0000)
#   - studies (Local Centrality: 0.0000)
#   - ...
#
# - Community 6 (13 members):
#   - community (Local Centrality: 0.0833)
#   - practice (Local Centrality: 0.0530)
#   - metascience (Local Centrality: 0.0303)
#   - bias (Local Centrality: 0.0303)
#   - trials (Local Centrality: 0.0152)
#   - monitoring (Local Centrality: 0.0000)
#   - engagement (Local Centrality: 0.0000)
#   - collabration (Local Centrality: 0.0000)
#   - training (Local Centrality: 0.0000)
#   - society (Local Centrality: 0.0000)
#   - ...

# %% [markdown]
# # Level 2 Knowledge Graph & Article Citations Multilayer Network

# %%
import pandas as pd
from pyvis.network import Network
import networkx as nx
import collections

# --- 1. DEFINE FILE PATHS ---
multilayer_path = '/Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/P5_gephi/multilayer/'
relations_file = '/Users/nil.ilba/Documents/2.Research/MA4_OpenEdition/P5_gephi/html_web/relations_final_entities.csv'
id_mapping_file = f'{multilayer_path}Alex_all_211.xlsx'
citation_nodes_file = f'{multilayer_path}gexf_nodes.csv'
citation_edges_file = f'{multilayer_path}gexf_edges.csv'


# --- 2. LOAD AND PREPARE ALL DATA SOURCES ---
print("--- Loading and Preparing Data ---")
try:
    df_relations = pd.read_csv(relations_file)
    df_id_map = pd.read_excel(id_mapping_file, sheet_name='Sheet1') 
    df_cite_nodes = pd.read_csv(citation_nodes_file)
    df_cite_edges = pd.read_csv(citation_edges_file)
    print("All data files loaded successfully.")
except Exception as e:
    print(f"Error loading files: {e}")
    exit()

# --- 3. IDENTIFY ALL UNIQUE ARTICLES AND THEMES ---
# Create the mapping from numeric ID to OpenAlex URL
try:
    id_map = pd.Series(df_id_map['id'].values, index=df_id_map['no']).to_dict()
    print(f"Created a map for {len(id_map)} article IDs.")
except KeyError:
    print("Error: Could not find 'id' or 'no' columns in the ID mapping file. Please check the column names.")
    exit()

# Helper function to parse article strings
def parse_article_string(article_str):
    if pd.isna(article_str): return []
    return [int(art_id.strip()) for art_id in str(article_str).split(',') if art_id.strip().isdigit()]

# Find all unique OpenAlex IDs mentioned in the entire relations file
articles_to_keep = set()
for _, row in df_relations.iterrows():
    subject_article_ids = parse_article_string(row.get('subject_articles'))
    for numeric_id in subject_article_ids:
        openalex_id = id_map.get(numeric_id)
        if openalex_id:
            articles_to_keep.add(openalex_id)
            
    object_article_ids = parse_article_string(row.get('object_articles'))
    for numeric_id in object_article_ids:
        openalex_id = id_map.get(numeric_id)
        if openalex_id:
            articles_to_keep.add(openalex_id)

print(f"Identified {len(articles_to_keep)} unique articles connected to any thematic concept.")

# --- 4. FILTER THE CITATION NETWORK ---
print("\n--- Filtering the Citation Network ---")
# Filter the nodes to keep only the relevant articles
filtered_cite_nodes = df_cite_nodes[df_cite_nodes['id'].isin(articles_to_keep)].copy()
print(f"Filtered down to {len(filtered_cite_nodes)} nodes in the citation network.")

# Filter the edges to keep only connections between the remaining nodes
filtered_cite_edges = df_cite_edges[
    df_cite_edges['source'].isin(filtered_cite_nodes['id']) &
    df_cite_edges['target'].isin(filtered_cite_nodes['id'])
].copy()
print(f"Filtered down to {len(filtered_cite_edges)} edges in the citation network.")

# --- 5. BUILD THE MULTILAYER NETWORK ---
print("\n--- Building the Multilayer Network Visualization ---")
net = Network(height='100vh', width='100%', bgcolor='white', font_color='#222222', directed=True, notebook=True)

# --- A. Add Filtered Citation Layer (Articles) ---
for _, row in filtered_cite_nodes.iterrows():
    # Set label to an empty space to hide it, but keep title for hover
    net.add_node(row['id'], label=' ', color='#CCCCCC', shape='dot', value=10, title=row['label'])
print(f"Added {len(filtered_cite_nodes)} article nodes to the graph.")

# --- B. Add Thematic Layer (Label 2 entities) ---
thematic_nodes = set(df_relations['subject_Label2'].dropna()) | set(df_relations['object_Label2'].dropna())
node_to_group = {row['subject_Label2']: row['subject_Label1'] for _, row in df_relations.iterrows() if pd.notna(row['subject_Label2'])}
node_to_group.update({row['object_Label2']: row['object_Label1'] for _, row in df_relations.iterrows() if pd.notna(row['object_Label2'])})

# Updated color map as per your request
defined_color_map = {
    'Economy': '#1f77b4', 'Ecosystem': '#ff7f0e', 'Events': '#2ca02c', 
    'Fields and Disciplines': '#d62728', 'Frameworks': '#9467bd', 'Institutional Action': '#8c564b',
    'Open Access': '#e377c2', 'Open Data': '#7f7f7f', 'Open Government': '#bcbd22',
    'Open Innovation': '#17becf', 'Open Science': '#aec7e8', 'Policies': '#ffbb78',
    'Research Outputs / Resources': '#98df8a', 'Research Processes / Practices': '#ff9896',
    'Research Values / Virtues': '#c5b0d5', 'Science and Society': '#c49c94',
    'Sociotechnical Devices': '#f7b6d2', 'Stakeholders/Actors': '#c7c7c7'
}

for node in thematic_nodes:
    group = node_to_group.get(node, 'Unknown')
    color = defined_color_map.get(group, '#E0E0E0')
    net.add_node(node, label=node, color=color, shape='box', value=20, title=f"Category: {group}")
print(f"Added {len(thematic_nodes)} thematic nodes to the graph.")

# --- C. Add Edges ---
# Add citation edges
for _, row in filtered_cite_edges.iterrows():
    net.add_edge(row['source'], row['target'], color='black', width=1.5, arrows='to')
print(f"Added {len(filtered_cite_edges)} citation edges.")

# Add connecting edges (Theme -> Article)
connecting_edge_count = 0
for _, row in df_relations.iterrows():
    subject_articles = parse_article_string(row.get('subject_articles'))
    for num_id in subject_articles:
        alex_id = id_map.get(num_id)
        if alex_id in articles_to_keep and pd.notna(row['subject_Label2']):
            net.add_edge(row['subject_Label2'], alex_id, color='#fad29b', width=1, dashes=True, arrows='to')
            connecting_edge_count += 1
            
    object_articles = parse_article_string(row.get('object_articles'))
    for num_id in object_articles:
        alex_id = id_map.get(num_id)
        if alex_id in articles_to_keep and pd.notna(row['object_Label2']):
            net.add_edge(row['object_Label2'], alex_id, color='#fad29b', width=1, dashes=True, arrows='to')
            connecting_edge_count += 1
print(f"Added {connecting_edge_count} connecting edges between themes and articles.")

# --- 6. SET OPTIONS AND GENERATE HTML ---
print("\n--- Generating Interactive HTML File ---")
net.set_options("""
const options = {
  "configure": { "enabled": true, "filter": "physics" },
  "nodes": { "font": { "size": 20 } },
  "edges": { "smooth": { "type": "continuous" } },
  "physics": {
    "forceAtlas2Based": {
      "gravitationalConstant": -80,
      "centralGravity": 0.01,
      "springLength": 200
    },
    "minVelocity": 0.75,
    "solver": "forceAtlas2Based"
  },
  "interaction": { "hover": true, "navigationButtons": true, "tooltipDelay": 200 }
}
""")

output_filename = f'{multilayer_path}multilayer_thematic_citation_network_v2.html'
try:
    net.show(output_filename)
    print(f"\n✅ Success! Multilayer network saved as '{output_filename}'")
except Exception as e:
    print(f"\nAn error occurred while saving the file: {e}")
